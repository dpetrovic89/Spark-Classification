# %% [markdown]
# # Classification in PySpark's MLlib Project Solution
#
# ### Genre classification
# Now it's time to leverage what we learned in the lectures to a REAL classification project! Have you ever wondered what makes us, humans, able to tell apart two songs of different genres? How we do we inherenly know the difference between a pop song and heavy metal? This type of classifcation may seem easy for us, but it's a very difficult challenge for a computer to do. So the question is, could an automatic genre classifcation model be possible?
#
# For this project we will be classifying songs based on a number of characteristics into a set of 23 electronic genres. This technology could be used by an application like Pandora to recommend songs to users or just create meaningful channels. Super fun!
#
# ### Dataset
# *beatsdataset.csv*
# Each row is an electronic music song. The dataset contains 100 song for each genre among 23 electronic music genres, they were the top (100) songs of their genres on November 2016. The 71 columns are audio features extracted of a two random minutes sample of the file audio. These features have been extracted using pyAudioAnalysis (https://github.com/tyiannak/pyAudioAnalysis).
#
# ### Your task
# Create an algorithm that classifies songs into the 23 genres provided. Test out several different models and select the highest performing one. Also play around with feature selection methods and finally try to make a recommendation to a user.
#
# For the feature selection aspect of this project, you may need to get a bit creative if you want to select features from a non-tree algorithm. I did not go over this aspect of PySpark intentionally in the previous lectures to give you chance to get used to researching the PySpark documentation page. Here is the link to the Feature Selectors section of the documentation that just might come in handy: https://spark.apache.org/docs/latest/ml-features.html#feature-selectors
#
# Good luck! Have fun :)
#
# ### Source
# https://www.kaggle.com/caparrini/beatsdataset

# %%
import findspark
findspark.init()

# %%
import pyspark
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('Genre').getOrCreate()

cores = spark._jsc.sc().getExecutorMemoryStatus().keySet().size()
print('You are working with', cores, 'core(s)')
spark
# Out:
# You are working with 1 core(s)
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-PSF4M3B:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Genre</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
path = 'Dataset/'

df = spark.read.csv(path+'beatsdataset.csv', inferSchema=True, header=True)

# %%
df.limit(5).toPandas()
# Out:
#    _c0    1-ZCRm  2-Energym  3-EnergyEntropym  4-SpectralCentroidm  \
# 0    0  0.136440   0.088861          3.201201             0.262825
# 1    1  0.117039   0.108389          3.194001             0.247657
# 2    2  0.085308   0.128525          3.123837             0.217205
# 3    3  0.103050   0.167042          3.150830             0.233593
# 4    4  0.151730   0.148405          3.194498             0.293730
#
#    5-SpectralSpreadm  6-SpectralEntropym  7-SpectralFluxm  8-SpectralRolloffm  \
# 0           0.249212            1.114423         0.007003            0.256682
# 1           0.250288            1.065668         0.005387            0.199821
# 2           0.228652            0.789647         0.008247            0.156822
# 3           0.245032            0.967082         0.006571            0.168083
# 4           0.267231            1.353005         0.003872            0.292055
#
#    9-MFCCs1m  ...  63-ChromaVector8std  64-ChromaVector9std  \
# 0 -22.723259  ...             0.003431             0.004981
# 1 -21.775871  ...             0.004461             0.006441
# 2 -22.472722  ...             0.001529             0.004556
# 3 -21.470751  ...             0.001591             0.003514
# 4 -21.371157  ...             0.003945             0.004131
#
#    65-ChromaVector10std  66-ChromaVector11std  67-ChromaVector12std  \
# 0              0.010818              0.024001              0.005201
# 1              0.007469              0.015499              0.005589
# 2              0.007723              0.017482              0.002901
# 3              0.009477              0.023162              0.004165
# 4              0.011330              0.028188              0.002639
#
#    68-ChromaDeviationstd      69-BPM  70-BPMconf  71-BPMessentia    class
# 0               0.015056  133.333333    0.132792           128.0  BigRoom
# 1               0.019339  120.000000    0.112767           126.0  BigRoom
# 2               0.022201  133.333333    0.123373           129.0  BigRoom
# 3               0.015379  133.333333    0.158876           129.0  BigRoom
# 4               0.019079  133.333333    0.190708           129.0  BigRoom
#
# [5 rows x 73 columns]

# %%
df.printSchema()
# Out:
# root
#  |-- _c0: integer (nullable = true)
#  |-- 1-ZCRm: double (nullable = true)
#  |-- 2-Energym: double (nullable = true)
#  |-- 3-EnergyEntropym: double (nullable = true)
#  |-- 4-SpectralCentroidm: double (nullable = true)
#  |-- 5-SpectralSpreadm: double (nullable = true)
#  |-- 6-SpectralEntropym: double (nullable = true)
#  |-- 7-SpectralFluxm: double (nullable = true)
#  |-- 8-SpectralRolloffm: double (nullable = true)
#  |-- 9-MFCCs1m: double (nullable = true)
#  |-- 10-MFCCs2m: double (nullable = true)
#  |-- 11-MFCCs3m: double (nullable = true)
#  |-- 12-MFCCs4m: double (nullable = true)
#  |-- 13-MFCCs5m: double (nullable = true)
#  |-- 14-MFCCs6m: double (nullable = true)
#  |-- 15-MFCCs7m: double (nullable = true)
#  |-- 16-MFCCs8m: double (nullable = true)
#  |-- 17-MFCCs9m: double (nullable = true)
#  |-- 18-MFCCs10m: double (nullable = true)
#  |-- 19-MFCCs11m: double (nullable = true)
#  |-- 20-MFCCs12m: double (nullable = true)
#  |-- 21-MFCCs13m: double (nullable = true)
#  |-- 22-ChromaVector1m: double (nullable = true)
#  |-- 23-ChromaVector2m: double (nullable = true)
#  |-- 24-ChromaVector3m: double (nullable = true)
#  |-- 25-ChromaVector4m: double (nullable = true)
#  |-- 26-ChromaVector5m: double (nullable = true)
#  |-- 27-ChromaVector6m: double (nullable = true)
#  |-- 28-ChromaVector7m: double (nullable = true)
#  |-- 29-ChromaVector8m: double (nullable = true)
#  |-- 30-ChromaVector9m: double (nullable = true)
#  |-- 31-ChromaVector10m: double (nullable = true)
#  |-- 32-ChromaVector11m: double (nullable = true)
#  |-- 33-ChromaVector12m: double (nullable = true)
#  |-- 34-ChromaDeviationm: double (nullable = true)
#  |-- 35-ZCRstd: double (nullable = true)
#  |-- 36-Energystd: double (nullable = true)
#  |-- 37-EnergyEntropystd: double (nullable = true)
#  |-- 38-SpectralCentroidstd: double (nullable = true)
#  |-- 39-SpectralSpreadstd: double (nullable = true)
#  |-- 40-SpectralEntropystd: double (nullable = true)
#  |-- 41-SpectralFluxstd: double (nullable = true)
#  |-- 42-SpectralRolloffstd: double (nullable = true)
#  |-- 43-MFCCs1std: double (nullable = true)
#  |-- 44-MFCCs2std: double (nullable = true)
#  |-- 45-MFCCs3std: double (nullable = true)
#  |-- 46-MFCCs4std: double (nullable = true)
#  |-- 47-MFCCs5std: double (nullable = true)
#  |-- 48-MFCCs6std: double (nullable = true)
#  |-- 49-MFCCs7std: double (nullable = true)
#  |-- 50-MFCCs8std: double (nullable = true)
#  |-- 51-MFCCs9std: double (nullable = true)
#  |-- 52-MFCCs10std: double (nullable = true)
#  |-- 53-MFCCs11std: double (nullable = true)
#  |-- 54-MFCCs12std: double (nullable = true)
#  |-- 55-MFCCs13std: double (nullable = true)
#  |-- 56-ChromaVector1std: double (nullable = true)
#  |-- 57-ChromaVector2std: double (nullable = true)
#  |-- 58-ChromaVector3std: double (nullable = true)
#  |-- 59-ChromaVector4std: double (nullable = true)
#  |-- 60-ChromaVector5std: double (nullable = true)
#  |-- 61-ChromaVector6std: double (nullable = true)
#  |-- 62-ChromaVector7std: double (nullable = true)
#  |-- 63-ChromaVector8std: double (nullable = true)
#  |-- 64-ChromaVector9std: double (nullable = true)
#  |-- 65-ChromaVector10std: double (nullable = true)
#  |-- 66-ChromaVector11std: double (nullable = true)
#  |-- 67-ChromaVector12std: double (nullable = true)
#  |-- 68-ChromaDeviationstd: double (nullable = true)
#  |-- 69-BPM: double (nullable = true)
#  |-- 70-BPMconf: double (nullable = true)
#  |-- 71-BPMessentia: double (nullable = true)
#  |-- class: string (nullable = true)

# %% [markdown]
# ### How many classes do we have?

# %%
df.groupBy('class').count().show(100)
# Out:
# +--------------------+-----+
# |               class|count|
# +--------------------+-----+
# |           PsyTrance|  100|
# |           HardDance|  100|
# |              Breaks|  100|
# |  HardcoreHardTechno|  100|
# |   IndieDanceNuDisco|  100|
# |              Trance|  100|
# |           DeepHouse|  100|
# |ElectronicaDowntempo|  100|
# |           ReggaeDub|  100|
# |             Minimal|  100|
# |         DrumAndBass|  100|
# |             Dubstep|  100|
# |             BigRoom|  100|
# |              Techno|  100|
# |               House|  100|
# |         FutureHouse|  100|
# |        ElectroHouse|  100|
# |           GlitchHop|  100|
# |           TechHouse|  100|
# |              HipHop|  100|
# |           FunkRAndB|  100|
# |               Dance|  100|
# |    ProgressiveHouse|  100|
# +--------------------+-----+

# %%
df.columns
# Out:
# ['_c0',
#  '1-ZCRm',
#  '2-Energym',
#  '3-EnergyEntropym',
#  '4-SpectralCentroidm',
#  '5-SpectralSpreadm',
#  '6-SpectralEntropym',
#  '7-SpectralFluxm',
#  '8-SpectralRolloffm',
#  '9-MFCCs1m',
#  '10-MFCCs2m',
#  '11-MFCCs3m',
#  '12-MFCCs4m',
#  '13-MFCCs5m',
#  '14-MFCCs6m',
#  '15-MFCCs7m',
#  '16-MFCCs8m',
#  '17-MFCCs9m',
#  '18-MFCCs10m',
#  '19-MFCCs11m',
#  '20-MFCCs12m',
#  '21-MFCCs13m',
#  '22-ChromaVector1m',
#  '23-ChromaVector2m',
#  '24-ChromaVector3m',
#  '25-ChromaVector4m',
#  '26-ChromaVector5m',
#  '27-ChromaVector6m',
#  '28-ChromaVector7m',
#  '29-ChromaVector8m',
#  '30-ChromaVector9m',
#  '31-ChromaVector10m',
#  '32-ChromaVector11m',
#  '33-ChromaVector12m',
#  '34-ChromaDeviationm',
#  '35-ZCRstd',
#  '36-Energystd',
#  '37-EnergyEntropystd',
#  '38-SpectralCentroidstd',
#  '39-SpectralSpreadstd',
#  '40-SpectralEntropystd',
#  '41-SpectralFluxstd',
#  '42-SpectralRolloffstd',
#  '43-MFCCs1std',
#  '44-MFCCs2std',
#  '45-MFCCs3std',
#  '46-MFCCs4std',
#  '47-MFCCs5std',
#  '48-MFCCs6std',
#  '49-MFCCs7std',
#  '50-MFCCs8std',
#  '51-MFCCs9std',
#  '52-MFCCs10std',
#  '53-MFCCs11std',
#  '54-MFCCs12std',
#  '55-MFCCs13std',
#  '56-ChromaVector1std',
#  '57-ChromaVector2std',
#  '58-ChromaVector3std',
#  '59-ChromaVector4std',
#  '60-ChromaVector5std',
#  '61-ChromaVector6std',
#  '62-ChromaVector7std',
#  '63-ChromaVector8std',
#  '64-ChromaVector9std',
#  '65-ChromaVector10std',
#  '66-ChromaVector11std',
#  '67-ChromaVector12std',
#  '68-ChromaDeviationstd',
#  '69-BPM',
#  '70-BPMconf',
#  '71-BPMessentia',
#  'class']

# %%
# Data Prep function
def MLClassifierDFPrep(df,input_columns,dependent_var,treat_outliers=True,treat_neg_values=True):
    
    # change label (class variable) to string type to prep for reindexing
    # Pyspark is expecting a zero indexed integer for the label column. 
    # Just incase our data is not in that format... we will treat it by using the StringIndexer built in method
    renamed = df.withColumn("label_str", df[dependent_var].cast(StringType())) #Rename and change to string type
    indexer = StringIndexer(inputCol="label_str", outputCol="label") #Pyspark is expecting the this naming convention 
    indexed = indexer.fit(renamed).transform(renamed)

    # Convert all string type data in the input column list to numeric
    # Otherwise the Algorithm will not be able to process it
    numeric_inputs = []
    string_inputs = []
    for column in input_columns:
        if str(indexed.schema[column].dataType) == 'StringType':
            indexer = StringIndexer(inputCol=column, outputCol=column+"_num") 
            indexed = indexer.fit(indexed).transform(indexed)
            new_col_name = column+"_num"
            string_inputs.append(new_col_name)
        else:
            numeric_inputs.append(column)
            
    if treat_outliers == True:
        print("We are correcting for non normality now!")
        # empty dictionary d
        d = {}
        # Create a dictionary of quantiles
        for col in numeric_inputs: 
            d[col] = indexed.approxQuantile(col,[0.01,0.99],0.25) #if you want to make it go faster increase the last number
        #Now fill in the values
        for col in numeric_inputs:
            skew = indexed.agg(skewness(indexed[col])).collect() #check for skewness
            skew = skew[0][0]
            # This function will floor, cap and then log+1 (just in case there are 0 values)
            if skew > 1:
                indexed = indexed.withColumn(col, \
                log(when(df[col] < d[col][0],d[col][0])\
                .when(indexed[col] > d[col][1], d[col][1])\
                .otherwise(indexed[col] ) +1).alias(col))
                print(col+" has been treated for positive (right) skewness. (skew =)",skew,")")
            elif skew < -1:
                indexed = indexed.withColumn(col, \
                exp(when(df[col] < d[col][0],d[col][0])\
                .when(indexed[col] > d[col][1], d[col][1])\
                .otherwise(indexed[col] )).alias(col))
                print(col+" has been treated for negative (left) skewness. (skew =",skew,")")

            
    # Produce a warning if there are negative values in the dataframe that Naive Bayes cannot be used. 
    # Note: we only need to check the numeric input values since anything that is indexed won't have negative values
    minimums = df.select([min(c).alias(c) for c in df.columns if c in numeric_inputs]) # Calculate the mins for all columns in the df
    min_array = minimums.select(array(numeric_inputs).alias("mins")) # Create an array for all mins and select only the input cols
    df_minimum = min_array.select(array_min(min_array.mins)).collect() # Collect golobal min as Python object
    df_minimum = df_minimum[0][0] # Slice to get the number itself

    features_list = numeric_inputs + string_inputs
    assembler = VectorAssembler(inputCols=features_list,outputCol='features')
    output = assembler.transform(indexed).select('features','label')

#     final_data = output.select('features','label') #drop everything else
    
    # Now check for negative values and ask user if they want to correct that? 
    if df_minimum < 0:
        print(" ")
        print("WARNING: The Naive Bayes Classifier will not be able to process your dataframe as it contains negative values")
        print(" ")
    
    if treat_neg_values == True:
        print("You have opted to correct that by rescaling all your features to a range of 0 to 1")
        print(" ")
        print("We are rescaling you dataframe....")
        scaler = MinMaxScaler(inputCol="features", outputCol="scaledFeatures")

        # Compute summary statistics and generate MinMaxScalerModel
        scalerModel = scaler.fit(output)

        # rescale each feature to range [min, max].
        scaled_data = scalerModel.transform(output)
        final_data = scaled_data.select('label','scaledFeatures')
        final_data = final_data.withColumnRenamed('scaledFeatures','features')
        print("Done!")

    else:
        print("You have opted not to correct that therefore you will not be able to use to Naive Bayes classifier")
        print("We will return the dataframe unscaled.")
        final_data = output
    
    return final_data

# %%
# Read in dependencies
from pyspark.ml.feature import VectorAssembler, StringIndexer, MinMaxScaler
from pyspark.sql.types import * 

from pyspark.ml.classification import *
from pyspark.ml.evaluation import *
from pyspark.sql.functions import *
from pyspark.ml.tuning import CrossValidator, ParamGridBuilder

# %%
input_columns = df.columns
input_columns = input_columns[1:-1]

# %%
dependent_var = 'class'

# %%
final_data = MLClassifierDFPrep(df,input_columns,dependent_var)
final_data.limit(5).toPandas()
# Out:
# We are correcting for non normality now!
# 7-SpectralFluxm has been treated for positive (right) skewness. (skew =) 1.6396138160129063 )
# 22-ChromaVector1m has been treated for positive (right) skewness. (skew =) 2.4162415204309258 )
# 23-ChromaVector2m has been treated for positive (right) skewness. (skew =) 4.154796693680583 )
# 24-ChromaVector3m has been treated for positive (right) skewness. (skew =) 1.1974019617504328 )
# 25-ChromaVector4m has been treated for positive (right) skewness. (skew =) 2.446635863594906 )
# 26-ChromaVector5m has been treated for positive (right) skewness. (skew =) 2.154482876187508 )
# 27-ChromaVector6m has been treated for positive (right) skewness. (skew =) 2.01234064472543 )
# 28-ChromaVector7m has been treated for positive (right) skewness. (skew =) 1.1829228989215521 )
# 29-ChromaVector8m has been treated for positive (right) skewness. (skew =) 3.7372643733999955 )
# 30-ChromaVector9m has been treated for positive (right) skewness. (skew =) 2.4117416421548645 )
# 31-ChromaVector10m has been treated for positive (right) skewness. (skew =) 2.1979538518563233 )
# 32-ChromaVector11m has been treated for positive (right) skewness. (skew =) 2.1924295373960554 )
# 33-ChromaVector12m has been treated for positive (right) skewness. (skew =) 2.278981912155668 )
# 41-SpectralFluxstd has been treated for positive (right) skewness. (skew =) 1.8577721462401056 )
# 56-ChromaVector1std has been treated for positive (right) skewness. (skew =) 1.9111935514138085 )
# 57-ChromaVector2std has been treated for positive (right) skewness. (skew =) 2.9078740765487394 )
# 59-ChromaVector4std has been treated for positive (right) skewness. (skew =) 2.9677243313898827 )
# 60-ChromaVector5std has been treated for positive (right) skewness. (skew =) 2.3681450229993315 )
# 61-ChromaVector6std has been treated for positive (right) skewness. (skew =) 2.3950817653605396 )
# 63-ChromaVector8std has been treated for positive (right) skewness. (skew =) 2.801578595136121 )
# 64-ChromaVector9std has been treated for positive (right) skewness. (skew =) 1.7779798465610313 )
# 65-ChromaVector10std has been treated for positive (right) skewness. (skew =) 1.9944501757850421 )
# 66-ChromaVector11std has been treated for positive (right) skewness. (skew =) 1.1835182964170816 )
# 67-ChromaVector12std has been treated for positive (right) skewness. (skew =) 2.087086908618814 )
# 69-BPM has been treated for positive (right) skewness. (skew =) 2.9547734198613234 )
# 70-BPMconf has been treated for positive (right) skewness. (skew =) 1.0889332324135428 )
#
# WARNING: The Naive Bayes Classifier will not be able to process your dataframe as it contains negative values
#
# You have opted to correct that by rescaling all your features to a range of 0 to 1
#
# We are rescaling you dataframe....
# Done!
#    label                                           features
# 0    0.0  [0.5198182667002392, 0.30338998025826874, 0.89...
# 1    0.0  [0.4352954639925659, 0.37399300906442695, 0.88...
# 2    0.0  [0.2970571291217422, 0.44679648775095127, 0.74...
# 3    0.0  [0.3743526477343687, 0.5860529526571694, 0.796...
# 4    0.0  [0.5864323374662597, 0.5186704525553854, 0.882...

# %% [markdown]
# ## Set up our Training and Evaluation Function

# %%
def ClassTrainEval(classifier,features,classes,folds,train,test):
    
    def FindMtype(classifier):
        # Intstantiate Model
        M = classifier
        # Learn what it is
        Mtype = type(M).__name__
        
        return Mtype
    
    Mtype = FindMtype(classifier)
    

    def IntanceFitModel(Mtype,classifier,classes,features,folds,train):
        
        if Mtype == "OneVsRest":
            # instantiate the base classifier.
            lr = LogisticRegression()
            # instantiate the One Vs Rest Classifier.
            OVRclassifier = OneVsRest(classifier=lr)
#             fitModel = OVRclassifier.fit(train)
            # Add parameters of your choice here:
            paramGrid = ParamGridBuilder() \
                .addGrid(lr.regParam, [0.1, 0.01]) \
                .build()
            #Cross Validator requires the following parameters:
            crossval = CrossValidator(estimator=OVRclassifier,
                                      estimatorParamMaps=paramGrid,
                                      evaluator=MulticlassClassificationEvaluator(),
                                      numFolds=folds) # 3 is best practice
            # Run cross-validation, and choose the best set of parameters.
            fitModel = crossval.fit(train)
            return fitModel
        if Mtype == "MultilayerPerceptronClassifier":
            # specify layers for the neural network:
            # input layer of size features, two intermediate of features+1 and same size as features
            # and output of size number of classes
            # Note: crossvalidator cannot be used here
            features_count = len(features[0][0])
            layers = [features_count, features_count+1, features_count, classes]
            MPC_classifier = MultilayerPerceptronClassifier(maxIter=100, layers=layers, blockSize=128, seed=1234)
            fitModel = MPC_classifier.fit(train)
            return fitModel
        if Mtype in("LinearSVC","GBTClassifier") and classes != 2: # These classifiers currently only accept binary classification
            print(Mtype," could not be used because PySpark currently only accepts binary classification data for this algorithm")
            return
        if Mtype in("LogisticRegression","NaiveBayes","RandomForestClassifier","GBTClassifier","LinearSVC","DecisionTreeClassifier"):
  
            # Add parameters of your choice here:
            if Mtype in("LogisticRegression"):
                paramGrid = (ParamGridBuilder() \
#                              .addGrid(classifier.regParam, [0.1, 0.01]) \
                             .addGrid(classifier.maxIter, [10, 15,20])
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("NaiveBayes"):
                paramGrid = (ParamGridBuilder() \
                             .addGrid(classifier.smoothing, [0.0, 0.2, 0.4, 0.6]) \
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("RandomForestClassifier"):
                paramGrid = (ParamGridBuilder() \
                               .addGrid(classifier.maxDepth, [2, 5, 10])
#                                .addGrid(classifier.maxBins, [5, 10, 20])
#                                .addGrid(classifier.numTrees, [5, 20, 50])
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("GBTClassifier"):
                paramGrid = (ParamGridBuilder() \
#                              .addGrid(classifier.maxDepth, [2, 5, 10, 20, 30]) \
#                              .addGrid(classifier.maxBins, [10, 20, 40, 80, 100]) \
                             .addGrid(classifier.maxIter, [10, 15,50,100])
                             .build())
                
            # Add parameters of your choice here:
            if Mtype in("LinearSVC"):
                paramGrid = (ParamGridBuilder() \
                             .addGrid(classifier.maxIter, [10, 15]) \
                             .addGrid(classifier.regParam, [0.1, 0.01]) \
                             .build())
            
            # Add parameters of your choice here:
            if Mtype in("DecisionTreeClassifier"):
                paramGrid = (ParamGridBuilder() \
#                              .addGrid(classifier.maxDepth, [2, 5, 10, 20, 30]) \
                             .addGrid(classifier.maxBins, [10, 20, 40, 80, 100]) \
                             .build())
            
            #Cross Validator requires all of the following parameters:
            crossval = CrossValidator(estimator=classifier,
                                      estimatorParamMaps=paramGrid,
                                      evaluator=MulticlassClassificationEvaluator(),
                                      numFolds=folds) # 3 + is best practice
            # Fit Model: Run cross-validation, and choose the best set of parameters.
            fitModel = crossval.fit(train)
            return fitModel
    
    fitModel = IntanceFitModel(Mtype,classifier,classes,features,folds,train)
    
    # Print feature selection metrics
    if fitModel is not None:
        
        if Mtype in("OneVsRest"):
            # Get Best Model
            BestModel = fitModel.bestModel
            global OVR_BestModel
            OVR_BestModel = BestModel
            print(" ")
            print('\033[1m' + Mtype + '\033[0m')
            # Extract list of binary models
            models = BestModel.models
            for model in models:
                print('\033[1m' + 'Intercept: '+ '\033[0m',model.intercept)
                print('\033[1m' + 'Top 20 Coefficients:'+ '\033[0m')
                coeff_array = model.coefficients.toArray()
                coeff_scores = []
                for x in coeff_array:
                    coeff_scores.append(float(x))
                # Then zip with input_columns list and create a df
                result = spark.createDataFrame(zip(input_columns,coeff_scores), schema=['feature','coeff'])
                print(result.orderBy(result["coeff"].desc()).show(truncate=False))


        if Mtype == "MultilayerPerceptronClassifier":
            print("")
            print('\033[1m' + Mtype + '\033[0m')
            print('\033[1m' + "Model Weights: "+ '\033[0m',fitModel.weights.size)
            print("")
            global MLPC_Model
            MLPC_BestModel = fitModel

        if Mtype in("DecisionTreeClassifier", "GBTClassifier","RandomForestClassifier"):
            # FEATURE IMPORTANCES
            # Estimate of the importance of each feature.
            # Each feature’s importance is the average of its importance across all trees 
            # in the ensemble The importance vector is normalized to sum to 1. 
            # Get Best Model
            BestModel = fitModel.bestModel
            print(" ")
            print('\033[1m' + Mtype," Top 20 Feature Importances"+ '\033[0m')
            print("(Scores add up to 1)")
            print("Lowest score is the least important")
            print(" ")
            featureImportances = BestModel.featureImportances.toArray()
            # Convert from numpy array to list
            imp_scores = []
            for x in featureImportances:
                imp_scores.append(float(x))
            # Then zip with input_columns list and create a df
            result = spark.createDataFrame(zip(input_columns,imp_scores), schema=['feature','score'])
            print(result.orderBy(result["score"].desc()).show(truncate=False))
            
            # Save the feature importance values and the models
            if Mtype in("DecisionTreeClassifier"):
                global DT_featureimportances
                DT_featureimportances = BestModel.featureImportances.toArray()
                global DT_BestModel
                DT_BestModel = BestModel
            if Mtype in("GBTClassifier"):
                global GBT_featureimportances
                GBT_featureimportances = BestModel.featureImportances.toArray()
                global GBT_BestModel
                GBT_BestModel = BestModel
            if Mtype in("RandomForestClassifier"):
                global RF_featureimportances
                RF_featureimportances = BestModel.featureImportances.toArray()
                global RF_BestModel
                RF_BestModel = BestModel

        # Print the coefficients
        if Mtype in("LogisticRegression"):
            # Get Best Model
            BestModel = fitModel.bestModel
            print(" ")
            print('\033[1m' + Mtype + '\033[0m')
            print("Intercept: " + str(BestModel.interceptVector))
            print('\033[1m' + " Top 20 Coefficients"+ '\033[0m')
            print("You should compares these relative to eachother")
            # Convert from numpy array to list
            coeff_array = BestModel.coefficientMatrix.toArray()
            coeff_scores = []
            for x in coeff_array[0]:
                coeff_scores.append(float(x))
            # Then zip with input_columns list and create a df
            result = spark.createDataFrame(zip(input_columns,coeff_scores), schema=['feature','coeff'])
            print(result.orderBy(result["coeff"].desc()).show(truncate=False))
            # Save the coefficient values and the models
            global LR_coefficients
            LR_coefficients = BestModel.coefficientMatrix.toArray()
            global LR_BestModel
            LR_BestModel = BestModel

        # Print the Coefficients
        if Mtype in("LinearSVC"):
            # Get Best Model
            BestModel = fitModel.bestModel
            print(" ")
            print('\033[1m' + Mtype + '\033[0m')
            print("Intercept: " + str(BestModel.intercept))
            print('\033[1m' + "Top 20 Coefficients"+ '\033[0m')
            print("You should compares these relative to eachother")
#             print("Coefficients: \n" + str(BestModel.coefficients))
            coeff_array = BestModel.coefficients.toArray()
            coeff_scores = []
            for x in coeff_array:
                coeff_scores.append(float(x))
            # Then zip with input_columns list and create a df
            result = spark.createDataFrame(zip(input_columns,coeff_scores), schema=['feature','coeff'])
            print(result.orderBy(result["coeff"].desc()).show(truncate=False))
            # Save the coefficient values and the models
            global LSVC_coefficients
            LSVC_coefficients = BestModel.coefficients.toArray()
            global LSVC_BestModel
            LSVC_BestModel = BestModel
        
   
    # Set the column names to match the external results dataframe that we will join with later:
    columns = ['Classifier', 'Result']
    
    if Mtype in("LinearSVC","GBTClassifier") and classes != 2:
        Mtype = [Mtype] # make this a list
        score = ["N/A"]
        result = spark.createDataFrame(zip(Mtype,score), schema=columns)
    else:
        predictions = fitModel.transform(test)
        MC_evaluator = MulticlassClassificationEvaluator(metricName="accuracy") # redictionCol="prediction",
        accuracy = (MC_evaluator.evaluate(predictions))*100
        Mtype = [Mtype] # make this a string
        score = [str(accuracy)] #make this a string and convert to a list
        result = spark.createDataFrame(zip(Mtype,score), schema=columns)
        result = result.withColumn('Result',result.Result.substr(0, 5))
        
    return result
    #Also returns the fit model important scores or p values

# %%
# Learn how many classes there are in order to specify evaluation type based on binary or multi and turn the df into an object
class_count = df.select(countDistinct("class")).collect()
classes = class_count[0][0]

# %% [markdown]
# ### Test 1: Without outlier treatment, skew or negative value treatment

# %%
# Call on data prep, train and evaluate functions
test1_data = MLClassifierDFPrep(df,input_columns,dependent_var,treat_outliers=False,treat_neg_values=False)
test1_data.limit(5).toPandas()

# Comment out Naive Bayes if your data still contains negative values
classifiers = [
                LogisticRegression()
                ,OneVsRest()
               ,LinearSVC()
#                ,NaiveBayes()
               ,RandomForestClassifier()
               ,GBTClassifier()
               ,DecisionTreeClassifier()
               ,MultilayerPerceptronClassifier()
              ] 

train,test = test1_data.randomSplit([0.7,0.3])
features = test1_data.select(['features']).collect()
folds = 2 # because we have limited data

#set up your results table
columns = ['Classifier', 'Result']
vals = [("Place Holder","N/A")]
results = spark.createDataFrame(vals, columns)

for classifier in classifiers:
    new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
    results = results.union(new_result)
results = results.where("Classifier!='Place Holder'")
print("!!!!!Final Results!!!!!!!!")
results.show(100,False)
# Out:
#
# WARNING: The Naive Bayes Classifier will not be able to process your dataframe as it contains negative values
#
# You have opted not to correct that therefore you will not be able to use to Naive Bayes classifier
# We will return the dataframe unscaled.
#
# LogisticRegression
# Intercept: [-0.03918683269121573,0.10629061147324848,-0.1065864936313428,-0.02530160676507121,0.034496261097686005,-0.01568447275965721,0.07148430706527434,-0.006469104558045878,-0.010080660578500456,0.0016804568433472636,-0.11804690649997898,-0.013000090552532753,0.001675831314454198,-0.015787443010099402,-0.012887699013786152,-0.022158003746879394,-0.0807630717469547,0.114346977176459,0.013704565767346572,-0.011610621446589229,0.03483436898985101,-0.0037299932606389913,0.102779620533626]
#  Top 20 Coefficients
# You should compares these relative to eachother
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |63-ChromaVector8std |35.32696925654321 |
# |29-ChromaVector8m   |23.263952303533493|
# |30-ChromaVector9m   |22.10130022377164 |
# |33-ChromaVector12m  |20.426708484887055|
# |67-ChromaVector12std|13.389715507714904|
# |22-ChromaVector1m   |11.441606711358466|
# |64-ChromaVector9std |8.558168041365088 |
# |5-SpectralSpreadm   |7.416558255520249 |
# |2-Energym           |7.01438059747974  |
# |53-MFCCs11std       |4.515281973891941 |
# |52-MFCCs10std       |3.9604816307947557|
# |3-EnergyEntropym    |3.7532818077149335|
# |24-ChromaVector3m   |3.0509543202319485|
# |54-MFCCs12std       |2.9706243996769714|
# |4-SpectralCentroidm |2.500650127542531 |
# |1-ZCRm              |2.465753903978532 |
# |58-ChromaVector3std |2.2894069124240612|
# |50-MFCCs8std        |1.800564256176671 |
# |51-MFCCs9std        |1.53732384230035  |
# |27-ChromaVector6m   |1.4985047996646403|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
#
# OneVsRest
# Intercept:  -3.139360555102745
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |27-ChromaVector6m   |23.751268765993032|
# |22-ChromaVector1m   |22.872379365060496|
# |30-ChromaVector9m   |22.78001775455008 |
# |63-ChromaVector8std |22.04139434874908 |
# |64-ChromaVector9std |13.988879126520116|
# |5-SpectralSpreadm   |11.528530195018401|
# |67-ChromaVector12std|11.199725823183927|
# |58-ChromaVector3std |6.815679711453126 |
# |52-MFCCs10std       |6.290776485104051 |
# |53-MFCCs11std       |5.73116996799896  |
# |62-ChromaVector7std |4.725746410783966 |
# |2-Energym           |4.205790298941857 |
# |50-MFCCs8std        |3.830410065641122 |
# |54-MFCCs12std       |3.492191375222757 |
# |24-ChromaVector3m   |2.91348459802158  |
# |36-Energystd        |2.7061461339084776|
# |3-EnergyEntropym    |2.7036918948483044|
# |26-ChromaVector5m   |2.5224858625657296|
# |18-MFCCs10m         |1.528122227877639 |
# |49-MFCCs7std        |1.3560019212756893|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.001982066477501
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |61-ChromaVector6std  |37.45016816123573 |
# |29-ChromaVector8m    |17.47267878739666 |
# |34-ChromaDeviationm  |16.730503926639795|
# |5-SpectralSpreadm    |9.810085205951872 |
# |65-ChromaVector10std |9.477019761638537 |
# |66-ChromaVector11std |7.3611052654037445|
# |42-SpectralRolloffstd|6.017009866318257 |
# |57-ChromaVector2std  |5.922285247421533 |
# |49-MFCCs7std         |5.543703574074376 |
# |28-ChromaVector7m    |4.49731554089555  |
# |32-ChromaVector11m   |3.906226407520766 |
# |24-ChromaVector3m    |3.4509154017359913|
# |46-MFCCs4std         |3.2165086666565266|
# |40-SpectralEntropystd|2.91917890366041  |
# |44-MFCCs2std         |2.474032732532653 |
# |68-ChromaDeviationstd|2.3856024759360563|
# |54-MFCCs12std        |1.5992857739388926|
# |45-MFCCs3std         |1.1399821716320278|
# |16-MFCCs8m           |1.1373973687903798|
# |51-MFCCs9std         |0.9842350909048637|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -11.325156862044176
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |63-ChromaVector8std   |83.0440334893742  |
# |29-ChromaVector8m     |58.479848650213874|
# |67-ChromaVector12std  |32.51894151322406 |
# |25-ChromaVector4m     |27.72241245724426 |
# |22-ChromaVector1m     |24.442355029766482|
# |36-Energystd          |15.078832940494864|
# |26-ChromaVector5m     |14.330772029543024|
# |41-SpectralFluxstd    |13.193510233419701|
# |38-SpectralCentroidstd|12.77915310288085 |
# |39-SpectralSpreadstd  |10.06170006043746 |
# |55-MFCCs13std         |9.922061129522714 |
# |60-ChromaVector5std   |8.982447603277661 |
# |51-MFCCs9std          |8.039183213397417 |
# |52-MFCCs10std         |6.715810415799701 |
# |53-MFCCs11std         |4.231790930135458 |
# |50-MFCCs8std          |3.433117183156134 |
# |3-EnergyEntropym      |3.1061937175549024|
# |17-MFCCs9m            |2.685530653455977 |
# |62-ChromaVector7std   |2.555302742057037 |
# |34-ChromaDeviationm   |2.257541420767127 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1442550171975627
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |164.38684158064387|
# |67-ChromaVector12std  |60.470594431906015|
# |38-SpectralCentroidstd|23.156341423962406|
# |33-ChromaVector12m    |14.271491528078686|
# |31-ChromaVector10m    |13.141158750940887|
# |64-ChromaVector9std   |12.454489328776203|
# |26-ChromaVector5m     |12.383050495571549|
# |36-Energystd          |10.588825126563345|
# |27-ChromaVector6m     |9.560394969305472 |
# |22-ChromaVector1m     |9.34768114893904  |
# |55-MFCCs13std         |9.007194230911459 |
# |30-ChromaVector9m     |8.47662139290977  |
# |34-ChromaDeviationm   |8.450944479962137 |
# |58-ChromaVector3std   |7.915316749280315 |
# |70-BPMconf            |7.177003256194141 |
# |66-ChromaVector11std  |7.073316802527276 |
# |35-ZCRstd             |6.284236294181787 |
# |39-SpectralSpreadstd  |5.496026639078255 |
# |53-MFCCs11std         |5.15116812665734  |
# |50-MFCCs8std          |4.684512345931797 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.029784884533371
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |59-ChromaVector4std  |41.8890557745092  |
# |23-ChromaVector2m    |35.2716048069484  |
# |33-ChromaVector12m   |34.659429815460236|
# |64-ChromaVector9std  |27.401223928830706|
# |5-SpectralSpreadm    |25.833219489199944|
# |26-ChromaVector5m    |21.20175980305002 |
# |2-Energym            |15.725729303334674|
# |60-ChromaVector5std  |11.81665001799499 |
# |4-SpectralCentroidm  |6.858085719276975 |
# |42-SpectralRolloffstd|5.807660813619327 |
# |66-ChromaVector11std |4.607211971178374 |
# |25-ChromaVector4m    |3.734865415879399 |
# |24-ChromaVector3m    |2.89906642080898  |
# |20-MFCCs12m          |2.781481604109323 |
# |34-ChromaDeviationm  |2.316360868898624 |
# |36-Energystd         |2.1304264528988854|
# |58-ChromaVector3std  |1.9001794700250494|
# |40-SpectralEntropystd|1.3896757711113614|
# |63-ChromaVector8std  |1.3201648357619038|
# |48-MFCCs6std         |1.2482063957904626|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1349184324277712
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |33-ChromaVector12m   |45.72589187871496 |
# |65-ChromaVector10std |41.25690956709432 |
# |68-ChromaDeviationstd|36.59789182380484 |
# |34-ChromaDeviationm  |29.5835074230591  |
# |59-ChromaVector4std  |28.355172504036947|
# |27-ChromaVector6m    |25.37081272876089 |
# |67-ChromaVector12std |14.388301702880446|
# |25-ChromaVector4m    |11.141986483298954|
# |36-Energystd         |10.170431879589904|
# |35-ZCRstd            |7.789537010960829 |
# |58-ChromaVector3std  |7.1822261973384265|
# |24-ChromaVector3m    |6.614545026914237 |
# |53-MFCCs11std        |6.490507536789699 |
# |41-SpectralFluxstd   |5.7284950870922735|
# |30-ChromaVector9m    |4.639075949176211 |
# |52-MFCCs10std        |3.415933955882758 |
# |4-SpectralCentroidm  |3.2336693354658155|
# |47-MFCCs5std         |3.089789995420924 |
# |8-SpectralRolloffm   |3.0446867373258235|
# |45-MFCCs3std         |2.8145914734753608|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0246774336434434
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |22-ChromaVector1m   |56.54990122028918 |
# |63-ChromaVector8std |38.939443490622544|
# |31-ChromaVector10m  |38.18284547567682 |
# |30-ChromaVector9m   |27.191371637259262|
# |25-ChromaVector4m   |20.846847133169184|
# |62-ChromaVector7std |9.127174965961409 |
# |2-Energym           |7.41882551980643  |
# |36-Energystd        |4.103048241809875 |
# |51-MFCCs9std        |3.6096115148087446|
# |5-SpectralSpreadm   |3.207837718641112 |
# |52-MFCCs10std       |2.8612807287314315|
# |58-ChromaVector3std |2.8087855674602213|
# |3-EnergyEntropym    |2.691632344291727 |
# |64-ChromaVector9std |2.6027197331907277|
# |49-MFCCs7std        |2.1113764487252364|
# |67-ChromaVector12std|1.7756302050980415|
# |53-MFCCs11std       |1.6393705389621531|
# |12-MFCCs4m          |1.3430149748156903|
# |19-MFCCs11m         |1.1834743298076722|
# |43-MFCCs1std        |1.1460654052729713|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0933461622016747
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |33-ChromaVector12m   |78.40570171898159 |
# |23-ChromaVector2m    |34.96512902221332 |
# |25-ChromaVector4m    |28.46696425096776 |
# |26-ChromaVector5m    |24.617219715453185|
# |41-SpectralFluxstd   |22.044866047931976|
# |32-ChromaVector11m   |16.01479917242101 |
# |61-ChromaVector6std  |15.232429444291325|
# |68-ChromaDeviationstd|14.871312278772063|
# |34-ChromaDeviationm  |8.81350337133445  |
# |62-ChromaVector7std  |8.144811491819882 |
# |36-Energystd         |6.946947636580017 |
# |48-MFCCs6std         |3.7760030840296785|
# |27-ChromaVector6m    |3.564171260162155 |
# |55-MFCCs13std        |3.44542974912502  |
# |54-MFCCs12std        |3.231939449417927 |
# |5-SpectralSpreadm    |2.891821942458617 |
# |49-MFCCs7std         |2.665762449429531 |
# |53-MFCCs11std        |2.1533459048101404|
# |37-EnergyEntropystd  |1.3127820493356415|
# |52-MFCCs10std        |1.194870525319472 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.069535485992076
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |64-ChromaVector9std  |88.03232670689954 |
# |63-ChromaVector8std  |72.61045767183415 |
# |57-ChromaVector2std  |58.4999324460578  |
# |56-ChromaVector1std  |33.620585964121894|
# |67-ChromaVector12std |31.510235777480954|
# |26-ChromaVector5m    |26.73870182211188 |
# |60-ChromaVector5std  |24.95719058402675 |
# |68-ChromaDeviationstd|21.471835290336983|
# |39-SpectralSpreadstd |20.614654571315036|
# |65-ChromaVector10std |14.434879794831035|
# |62-ChromaVector7std  |13.442459425858722|
# |32-ChromaVector11m   |12.23921897654765 |
# |22-ChromaVector1m    |11.782222350832042|
# |55-MFCCs13std        |8.840774417668758 |
# |50-MFCCs8std         |5.6826930536412466|
# |58-ChromaVector3std  |5.585717484075853 |
# |48-MFCCs6std         |5.112748347700202 |
# |36-Energystd         |4.688033002970227 |
# |59-ChromaVector4std  |4.195164280038578 |
# |52-MFCCs10std        |4.057753723181959 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1058273398020324
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |67-ChromaVector12std  |60.318284483001236|
# |57-ChromaVector2std   |29.689029540996163|
# |60-ChromaVector5std   |24.163943186533547|
# |23-ChromaVector2m     |19.487922331382148|
# |41-SpectralFluxstd    |18.67289053445253 |
# |38-SpectralCentroidstd|16.130861361415956|
# |61-ChromaVector6std   |14.31263871976422 |
# |62-ChromaVector7std   |11.210114694664364|
# |58-ChromaVector3std   |8.109486762783343 |
# |36-Energystd          |7.447974484500459 |
# |30-ChromaVector9m     |6.901557537413569 |
# |3-EnergyEntropym      |5.397675898533986 |
# |54-MFCCs12std         |5.246722491011897 |
# |2-Energym             |3.948350047188744 |
# |42-SpectralRolloffstd |3.919097784500817 |
# |35-ZCRstd             |3.677220769564869 |
# |53-MFCCs11std         |3.429637705198615 |
# |39-SpectralSpreadstd  |3.0414091536984156|
# |63-ChromaVector8std   |1.8665629873103282|
# |40-SpectralEntropystd |1.3258215655753884|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.187662118519223
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |56-ChromaVector1std  |103.12168308009768|
# |26-ChromaVector5m    |23.09834760265651 |
# |27-ChromaVector6m    |21.176670176964805|
# |59-ChromaVector4std  |20.629312803102017|
# |65-ChromaVector10std |16.709612857836106|
# |31-ChromaVector10m   |12.46095618588175 |
# |32-ChromaVector11m   |11.543604677154393|
# |62-ChromaVector7std  |11.527526764176349|
# |50-MFCCs8std         |9.189576016494879 |
# |58-ChromaVector3std  |5.79428952546755  |
# |66-ChromaVector11std |5.403143919016853 |
# |39-SpectralSpreadstd |5.368333878472719 |
# |41-SpectralFluxstd   |4.515175151726204 |
# |51-MFCCs9std         |4.4238750219250225|
# |53-MFCCs11std        |4.1048892520735984|
# |68-ChromaDeviationstd|3.182805772270053 |
# |48-MFCCs6std         |2.7993782644254304|
# |35-ZCRstd            |2.4046452271799157|
# |21-MFCCs13m          |2.2781881436811338|
# |52-MFCCs10std        |2.2557258539740075|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.122060770911675
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |63-ChromaVector8std  |88.64457860798524 |
# |67-ChromaVector12std |88.3486674630519  |
# |68-ChromaDeviationstd|26.843503827448085|
# |64-ChromaVector9std  |25.850688631360065|
# |70-BPMconf           |18.43522727740622 |
# |61-ChromaVector6std  |13.483695176648412|
# |33-ChromaVector12m   |9.163211829645812 |
# |2-Energym            |7.401641045181678 |
# |5-SpectralSpreadm    |6.795440331735503 |
# |52-MFCCs10std        |6.655141589346076 |
# |48-MFCCs6std         |5.1976742858649265|
# |28-ChromaVector7m    |3.096967956807056 |
# |58-ChromaVector3std  |2.9643541408789456|
# |46-MFCCs4std         |2.424019545359367 |
# |53-MFCCs11std        |2.3747188735674856|
# |51-MFCCs9std         |2.331293460584989 |
# |1-ZCRm               |2.2297356319882904|
# |47-MFCCs5std         |1.5916299532920228|
# |4-SpectralCentroidm  |0.8899878102042773|
# |16-MFCCs8m           |0.8585230779024107|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.763589236651076
# Top 20 Coefficients:
# +----------------------+-------------------+
# |feature               |coeff              |
# +----------------------+-------------------+
# |29-ChromaVector8m     |52.771027928721125 |
# |7-SpectralFluxm       |52.44636641133263  |
# |2-Energym             |13.81087149065319  |
# |56-ChromaVector1std   |12.3834986761294   |
# |1-ZCRm                |9.285494881738273  |
# |70-BPMconf            |8.341485144292337  |
# |38-SpectralCentroidstd|7.510402365562634  |
# |28-ChromaVector7m     |5.477144649725949  |
# |23-ChromaVector2m     |3.8906730644782552 |
# |45-MFCCs3std          |2.6589495858130165 |
# |13-MFCCs5m            |2.645492376646041  |
# |21-MFCCs13m           |2.252291927862711  |
# |62-ChromaVector7std   |2.0196489418326826 |
# |18-MFCCs10m           |1.5181251297865586 |
# |8-SpectralRolloffm    |1.4575604077021378 |
# |4-SpectralCentroidm   |1.3340906369476064 |
# |44-MFCCs2std          |0.9925647591626845 |
# |24-ChromaVector3m     |0.923239580495695  |
# |14-MFCCs6m            |0.4056137104649972 |
# |37-EnergyEntropystd   |0.37899815751191607|
# +----------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1285784023324994
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |63-ChromaVector8std   |67.21334105029878 |
# |27-ChromaVector6m     |66.15117719997141 |
# |29-ChromaVector8m     |61.62171270182628 |
# |34-ChromaDeviationm   |16.674661141647082|
# |36-Energystd          |16.517497057980265|
# |55-MFCCs13std         |15.985618675883472|
# |31-ChromaVector10m    |7.634689453799858 |
# |39-SpectralSpreadstd  |7.601200189242036 |
# |54-MFCCs12std         |7.165410368294816 |
# |52-MFCCs10std         |6.009487396122415 |
# |48-MFCCs6std          |4.313222868136129 |
# |44-MFCCs2std          |3.1658730951528025|
# |2-Energym             |2.9706858928910527|
# |60-ChromaVector5std   |2.9653575415662585|
# |46-MFCCs4std          |2.896051311061514 |
# |49-MFCCs7std          |2.8192881633606905|
# |18-MFCCs10m           |2.481020618830387 |
# |47-MFCCs5std          |1.7033476065735413|
# |38-SpectralCentroidstd|1.6567836643728477|
# |24-ChromaVector3m     |1.3922822253971165|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1110410843030265
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |88.45951076885791 |
# |64-ChromaVector9std   |88.12634122498228 |
# |63-ChromaVector8std   |81.03257298210963 |
# |25-ChromaVector4m     |25.59835442804075 |
# |60-ChromaVector5std   |24.85765475467467 |
# |31-ChromaVector10m    |15.339847846141383|
# |59-ChromaVector4std   |13.363520807866339|
# |38-SpectralCentroidstd|12.78350684352877 |
# |35-ZCRstd             |10.781010546038294|
# |55-MFCCs13std         |10.192538297233593|
# |46-MFCCs4std          |5.019583674405849 |
# |53-MFCCs11std         |3.7466225732574787|
# |42-SpectralRolloffstd |3.7171815623258286|
# |54-MFCCs12std         |2.609268844243488 |
# |52-MFCCs10std         |2.259081861812972 |
# |20-MFCCs12m           |1.7022572456917724|
# |17-MFCCs9m            |1.5853020112492613|
# |40-SpectralEntropystd |1.2406507267987814|
# |36-Energystd          |1.233561534362306 |
# |70-BPMconf            |1.1352564804743166|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1082777536344905
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |63-ChromaVector8std  |68.94508136572549 |
# |68-ChromaDeviationstd|66.26457184612637 |
# |33-ChromaVector12m   |64.67075456651337 |
# |39-SpectralSpreadstd |46.97262243100557 |
# |30-ChromaVector9m    |42.1957556868361  |
# |64-ChromaVector9std  |39.13857347574005 |
# |60-ChromaVector5std  |31.886500380238335|
# |29-ChromaVector8m    |31.421708258184413|
# |58-ChromaVector3std  |19.704686669044364|
# |36-Energystd         |18.077775110984575|
# |61-ChromaVector6std  |17.856199376850217|
# |22-ChromaVector1m    |14.721423080485062|
# |32-ChromaVector11m   |12.024531441761345|
# |5-SpectralSpreadm    |10.305595629864793|
# |23-ChromaVector2m    |9.973259475793355 |
# |65-ChromaVector10std |9.17399620754811  |
# |62-ChromaVector7std  |6.80278745305857  |
# |37-EnergyEntropystd  |4.625789402229706 |
# |48-MFCCs6std         |3.924400621646753 |
# |47-MFCCs5std         |3.903192025117343 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1901881543203947
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |130.78724639051416|
# |33-ChromaVector12m    |75.7514947130721  |
# |7-SpectralFluxm       |62.81576974505004 |
# |41-SpectralFluxstd    |50.717685420459134|
# |64-ChromaVector9std   |35.814972195063895|
# |39-SpectralSpreadstd  |28.11764063176476 |
# |30-ChromaVector9m     |26.691571404285014|
# |27-ChromaVector6m     |25.464896197296593|
# |59-ChromaVector4std   |24.484057662349542|
# |38-SpectralCentroidstd|17.608036741274443|
# |57-ChromaVector2std   |16.02094064970323 |
# |23-ChromaVector2m     |14.716347114454994|
# |25-ChromaVector4m     |12.22418404464615 |
# |34-ChromaDeviationm   |6.5691156133020385|
# |47-MFCCs5std          |4.887490665139325 |
# |58-ChromaVector3std   |4.35814587430474  |
# |21-MFCCs13m           |3.9429306809141482|
# |49-MFCCs7std          |3.1750270671712766|
# |28-ChromaVector7m     |2.6065311206347137|
# |15-MFCCs7m            |1.5508035659825212|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.9641202093578283
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |63-ChromaVector8std   |62.66116931932342 |
# |30-ChromaVector9m     |37.32552029529939 |
# |29-ChromaVector8m     |26.172679630040047|
# |26-ChromaVector5m     |24.131494719272844|
# |67-ChromaVector12std  |21.488863197132034|
# |36-Energystd          |17.413972336626838|
# |41-SpectralFluxstd    |17.195161187819558|
# |27-ChromaVector6m     |17.033531903756543|
# |65-ChromaVector10std  |16.660214904871708|
# |25-ChromaVector4m     |14.828173806719448|
# |32-ChromaVector11m    |13.96700229280171 |
# |38-SpectralCentroidstd|13.466440312586387|
# |31-ChromaVector10m    |11.607165545210906|
# |57-ChromaVector2std   |10.982390940540807|
# |61-ChromaVector6std   |9.839388430929425 |
# |58-ChromaVector3std   |9.06170541593603  |
# |54-MFCCs12std         |8.10127217507396  |
# |70-BPMconf            |6.239781269432067 |
# |64-ChromaVector9std   |4.644961036460373 |
# |42-SpectralRolloffstd |4.22548539861641  |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0429611910262615
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |29-ChromaVector8m    |102.90881979668987|
# |68-ChromaDeviationstd|81.90087463395845 |
# |67-ChromaVector12std |79.47663802566652 |
# |7-SpectralFluxm      |72.86177790719078 |
# |63-ChromaVector8std  |49.021160344348274|
# |41-SpectralFluxstd   |48.81707259372683 |
# |57-ChromaVector2std  |42.006347958761175|
# |27-ChromaVector6m    |25.388550953698157|
# |23-ChromaVector2m    |23.26016699215911 |
# |31-ChromaVector10m   |21.896522804089233|
# |62-ChromaVector7std  |19.95849993034509 |
# |61-ChromaVector6std  |18.44971195888707 |
# |66-ChromaVector11std |15.486756831529952|
# |33-ChromaVector12m   |11.580966962547619|
# |36-Energystd         |10.420289781097951|
# |64-ChromaVector9std  |9.814612488517838 |
# |26-ChromaVector5m    |8.237451397956537 |
# |30-ChromaVector9m    |4.645111028806584 |
# |49-MFCCs7std         |3.5129759563748846|
# |3-EnergyEntropym     |2.1402661118160067|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1005892359345353
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |63-ChromaVector8std  |97.09962913920542 |
# |68-ChromaDeviationstd|53.93356926935159 |
# |39-SpectralSpreadstd |47.20545208278971 |
# |59-ChromaVector4std  |42.22574446502156 |
# |27-ChromaVector6m    |41.98477094409784 |
# |25-ChromaVector4m    |35.53740328830739 |
# |66-ChromaVector11std |29.873427396422365|
# |67-ChromaVector12std |24.058588881663635|
# |34-ChromaDeviationm  |19.66035756031489 |
# |29-ChromaVector8m    |13.143223713120141|
# |65-ChromaVector10std |11.442681958557587|
# |55-MFCCs13std        |8.614799116365422 |
# |54-MFCCs12std        |6.806026349226318 |
# |47-MFCCs5std         |6.460952402863856 |
# |35-ZCRstd            |6.129616797694363 |
# |50-MFCCs8std         |4.710421331770051 |
# |49-MFCCs7std         |3.9450301904678846|
# |51-MFCCs9std         |3.812819664008866 |
# |53-MFCCs11std        |3.6214992176839416|
# |24-ChromaVector3m    |3.577848647863838 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0533693132980857
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |67-ChromaVector12std  |67.06847250389507 |
# |30-ChromaVector9m     |55.99961415434514 |
# |56-ChromaVector1std   |35.10063609013214 |
# |38-SpectralCentroidstd|15.23188415828086 |
# |41-SpectralFluxstd    |14.666064062551884|
# |26-ChromaVector5m     |13.698631997818717|
# |35-ZCRstd             |11.215388768776968|
# |60-ChromaVector5std   |10.920398064686282|
# |23-ChromaVector2m     |7.905046967809384 |
# |65-ChromaVector10std  |4.404701855968553 |
# |42-SpectralRolloffstd |3.7244549943367002|
# |37-EnergyEntropystd   |3.715175419707558 |
# |28-ChromaVector7m     |2.396104542198211 |
# |17-MFCCs9m            |2.1513551201520413|
# |1-ZCRm                |2.0877159953077102|
# |25-ChromaVector4m     |2.0084785758171892|
# |4-SpectralCentroidm   |1.857891749512165 |
# |47-MFCCs5std          |1.7235930964970567|
# |45-MFCCs3std          |1.4823400246388616|
# |54-MFCCs12std         |1.3818955040742675|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0756245621014613
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |63.38307319405846 |
# |30-ChromaVector9m     |60.728682802766855|
# |65-ChromaVector10std  |55.38108319307721 |
# |22-ChromaVector1m     |43.21392393398654 |
# |41-SpectralFluxstd    |29.46644139718309 |
# |56-ChromaVector1std   |28.033268601521257|
# |33-ChromaVector12m    |12.88548775847285 |
# |55-MFCCs13std         |11.186281085614068|
# |7-SpectralFluxm       |10.671215348433735|
# |23-ChromaVector2m     |10.285115799546784|
# |38-SpectralCentroidstd|10.024824982182997|
# |34-ChromaDeviationm   |9.755787484962827 |
# |66-ChromaVector11std  |9.27123871560617  |
# |59-ChromaVector4std   |8.013230432994614 |
# |60-ChromaVector5std   |7.821861144355275 |
# |36-Energystd          |6.32285140114111  |
# |32-ChromaVector11m    |6.255811780236407 |
# |28-ChromaVector7m     |4.6340703353786745|
# |5-SpectralSpreadm     |3.3145377906700597|
# |21-MFCCs13m           |3.2932665118804807|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.9861895701625087
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |33-ChromaVector12m  |42.29052436388119 |
# |31-ChromaVector10m  |36.353306950985576|
# |25-ChromaVector4m   |35.017454352271685|
# |65-ChromaVector10std|31.318766944997332|
# |23-ChromaVector2m   |30.88737895613705 |
# |56-ChromaVector1std |29.83344862880314 |
# |41-SpectralFluxstd  |28.054594284115538|
# |27-ChromaVector6m   |23.602070656948165|
# |59-ChromaVector4std |22.711938285616917|
# |66-ChromaVector11std|21.771249700053282|
# |30-ChromaVector9m   |17.95273603257814 |
# |60-ChromaVector5std |17.58174313765497 |
# |7-SpectralFluxm     |17.043783673055888|
# |5-SpectralSpreadm   |13.085392294504953|
# |22-ChromaVector1m   |13.006435923418188|
# |62-ChromaVector7std |11.574522189428174|
# |61-ChromaVector6std |6.657719534859626 |
# |3-EnergyEntropym    |4.15265243222154  |
# |19-MFCCs11m         |3.772079528727229 |
# |4-SpectralCentroidm |3.3834101565998997|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# LinearSVC  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# RandomForestClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +----------------------+--------------------+
# |feature               |score               |
# +----------------------+--------------------+
# |71-BPMessentia        |0.08353669226336584 |
# |69-BPM                |0.05564237158174522 |
# |2-Energym             |0.025983461683837934|
# |70-BPMconf            |0.02592861822032224 |
# |39-SpectralSpreadstd  |0.02273832349157299 |
# |1-ZCRm                |0.021484739744120886|
# |3-EnergyEntropym      |0.021087352158649715|
# |53-MFCCs11std         |0.02082526149905767 |
# |10-MFCCs2m            |0.019786855928974004|
# |52-MFCCs10std         |0.01977814710598529 |
# |54-MFCCs12std         |0.01932387408507293 |
# |38-SpectralCentroidstd|0.019299889420336974|
# |43-MFCCs1std          |0.017693387878641574|
# |7-SpectralFluxm       |0.017642120961392567|
# |45-MFCCs3std          |0.016652759605129148|
# |47-MFCCs5std          |0.015740071306808153|
# |50-MFCCs8std          |0.015598297988395873|
# |24-ChromaVector3m     |0.015147074651776324|
# |46-MFCCs4std          |0.014609154342689511|
# |55-MFCCs13std         |0.014438009205530131|
# +----------------------+--------------------+
# only showing top 20 rows
#
# None
# GBTClassifier  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# DecisionTreeClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +---------------------+--------------------+
# |feature              |score               |
# +---------------------+--------------------+
# |71-BPMessentia       |0.504970432957683   |
# |41-SpectralFluxstd   |0.09798925720907972 |
# |52-MFCCs10std        |0.07344668050000568 |
# |44-MFCCs2std         |0.05619353538233401 |
# |3-EnergyEntropym     |0.04392206372663899 |
# |9-MFCCs1m            |0.042828567909201164|
# |1-ZCRm               |0.037573253132972564|
# |47-MFCCs5std         |0.024750560943223487|
# |46-MFCCs4std         |0.024627896872859663|
# |43-MFCCs1std         |0.022684793096733647|
# |69-BPM               |0.015117314076805288|
# |70-BPMconf           |0.015097582252300165|
# |39-SpectralSpreadstd |0.015005906525598453|
# |37-EnergyEntropystd  |0.010295836466241161|
# |48-MFCCs6std         |0.006096912373110767|
# |10-MFCCs2m           |0.004899304585535437|
# |66-ChromaVector11std |0.004500101989677012|
# |40-SpectralEntropystd|0.0                 |
# |42-SpectralRolloffstd|0.0                 |
# |45-MFCCs3std         |0.0                 |
# +---------------------+--------------------+
# only showing top 20 rows
#
# None
#
# MultilayerPerceptronClassifier
# Model Weights:  12023
#
# !!!!!Final Results!!!!!!!!
# +------------------------------+------+
# |Classifier                    |Result|
# +------------------------------+------+
# |LogisticRegression            |40.57 |
# |OneVsRest                     |45.32 |
# |LinearSVC                     |N/A   |
# |RandomForestClassifier        |44.89 |
# |GBTClassifier                 |N/A   |
# |DecisionTreeClassifier        |32.94 |
# |MultilayerPerceptronClassifier|12.94 |
# +------------------------------+------+

# %% [markdown]
# ### Test 2: Test treatments
#
# Train and evaluate models on treated data (outliers, skewness and negative values) and compare to baseline (#1).

# %%
# Call on data prep, train and evaluate functions
test2_data = MLClassifierDFPrep(df,input_columns,dependent_var,treat_outliers=True,treat_neg_values=True)
test2_data.limit(5).toPandas()

# Comment out Naive Bayes if your data still contains negative values
classifiers = [
                LogisticRegression()
                ,OneVsRest()
               ,LinearSVC()
               ,NaiveBayes()
               ,RandomForestClassifier()
               ,GBTClassifier()
               ,DecisionTreeClassifier()
               ,MultilayerPerceptronClassifier()
              ] 

train,test = test2_data.randomSplit([0.7,0.3])
features = test2_data.select(['features']).collect()
folds = 2

#set up your results table
columns = ['Classifier', 'Result']
vals = [("Place Holder","N/A")]
results = spark.createDataFrame(vals, columns)

for classifier in classifiers:
    new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
    results = results.union(new_result)
results = results.where("Classifier!='Place Holder'")
print("!!!!!Final Results!!!!!!!!")
results.show(100,False)
# Out:
# We are correcting for non normality now!
# 7-SpectralFluxm has been treated for positive (right) skewness. (skew =) 1.6396138160129063 )
# 22-ChromaVector1m has been treated for positive (right) skewness. (skew =) 2.4162415204309258 )
# 23-ChromaVector2m has been treated for positive (right) skewness. (skew =) 4.154796693680583 )
# 24-ChromaVector3m has been treated for positive (right) skewness. (skew =) 1.1974019617504328 )
# 25-ChromaVector4m has been treated for positive (right) skewness. (skew =) 2.446635863594906 )
# 26-ChromaVector5m has been treated for positive (right) skewness. (skew =) 2.154482876187508 )
# 27-ChromaVector6m has been treated for positive (right) skewness. (skew =) 2.01234064472543 )
# 28-ChromaVector7m has been treated for positive (right) skewness. (skew =) 1.1829228989215521 )
# 29-ChromaVector8m has been treated for positive (right) skewness. (skew =) 3.7372643733999955 )
# 30-ChromaVector9m has been treated for positive (right) skewness. (skew =) 2.4117416421548645 )
# 31-ChromaVector10m has been treated for positive (right) skewness. (skew =) 2.1979538518563233 )
# 32-ChromaVector11m has been treated for positive (right) skewness. (skew =) 2.1924295373960554 )
# 33-ChromaVector12m has been treated for positive (right) skewness. (skew =) 2.278981912155668 )
# 41-SpectralFluxstd has been treated for positive (right) skewness. (skew =) 1.8577721462401056 )
# 56-ChromaVector1std has been treated for positive (right) skewness. (skew =) 1.9111935514138085 )
# 57-ChromaVector2std has been treated for positive (right) skewness. (skew =) 2.9078740765487394 )
# 59-ChromaVector4std has been treated for positive (right) skewness. (skew =) 2.9677243313898827 )
# 60-ChromaVector5std has been treated for positive (right) skewness. (skew =) 2.3681450229993315 )
# 61-ChromaVector6std has been treated for positive (right) skewness. (skew =) 2.3950817653605396 )
# 63-ChromaVector8std has been treated for positive (right) skewness. (skew =) 2.801578595136121 )
# 64-ChromaVector9std has been treated for positive (right) skewness. (skew =) 1.7779798465610313 )
# 65-ChromaVector10std has been treated for positive (right) skewness. (skew =) 1.9944501757850421 )
# 66-ChromaVector11std has been treated for positive (right) skewness. (skew =) 1.1835182964170816 )
# 67-ChromaVector12std has been treated for positive (right) skewness. (skew =) 2.087086908618814 )
# 69-BPM has been treated for positive (right) skewness. (skew =) 2.9547734198613234 )
# 70-BPMconf has been treated for positive (right) skewness. (skew =) 1.0889332324135428 )
#
# WARNING: The Naive Bayes Classifier will not be able to process your dataframe as it contains negative values
#
# You have opted to correct that by rescaling all your features to a range of 0 to 1
#
# We are rescaling you dataframe....
# Done!
#
# LogisticRegression
# Intercept: [0.002967780880933769,-0.1362721988711366,-0.008101509000601262,0.013798450167302146,0.06339457867359397,0.02843092149820505,-0.013142628910273622,-0.0030387551813865145,0.03474798588678535,-0.04180792305143293,-0.027671167802017407,-0.050642894592877734,0.09624163302559677,-0.014608654482574932,0.07336629738230593,-0.0041449253379898165,0.05623668239105812,0.0709458855999842,0.02186443497110867,-0.03711285919934307,-0.16199065506943833,-0.008010811093427767,0.04455033211562597]
#  Top 20 Coefficients
# You should compares these relative to eachother
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |9-MFCCs1m          |3.9773694891669438 |
# |71-BPMessentia     |2.0606484168329873 |
# |2-Energym          |2.01994799221115   |
# |3-EnergyEntropym   |1.7383630519704223 |
# |24-ChromaVector3m  |1.6652042110457932 |
# |5-SpectralSpreadm  |1.2091570379190915 |
# |18-MFCCs10m        |1.1103759331369045 |
# |22-ChromaVector1m  |1.0618372360189046 |
# |53-MFCCs11std      |0.9515041930117751 |
# |6-SpectralEntropym |0.8861382938597044 |
# |54-MFCCs12std      |0.8808193459225492 |
# |52-MFCCs10std      |0.8045880797367639 |
# |50-MFCCs8std       |0.6995164459472599 |
# |4-SpectralCentroidm|0.6504015749269146 |
# |63-ChromaVector8std|0.6020848198626527 |
# |58-ChromaVector3std|0.5417080123201822 |
# |13-MFCCs5m         |0.5222295403262874 |
# |12-MFCCs4m         |0.46329078893712095|
# |1-ZCRm             |0.4487490437534306 |
# |30-ChromaVector9m  |0.44828596992642433|
# +-------------------+-------------------+
# only showing top 20 rows
#
# None
#
# OneVsRest
# Intercept:  -3.3644225973365516
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |9-MFCCs1m          |4.270802710076053 |
# |22-ChromaVector1m  |2.3191100844999957|
# |71-BPMessentia     |2.2660099181457665|
# |43-MFCCs1std       |2.0047302508581324|
# |5-SpectralSpreadm  |1.5551608444142497|
# |24-ChromaVector3m  |1.4602563809463687|
# |12-MFCCs4m         |1.1611667481135568|
# |3-EnergyEntropym   |1.1068652821697444|
# |11-MFCCs3m         |1.1028835776534354|
# |53-MFCCs11std      |1.018156763321481 |
# |54-MFCCs12std      |0.9488059416490737|
# |2-Energym          |0.9311690534698308|
# |63-ChromaVector8std|0.9304226707671224|
# |52-MFCCs10std      |0.9160884956783365|
# |46-MFCCs4std       |0.8686456310872014|
# |18-MFCCs10m        |0.8649187898329888|
# |50-MFCCs8std       |0.8512241590215597|
# |47-MFCCs5std       |0.7174537714214797|
# |36-Energystd       |0.7023971174317338|
# |13-MFCCs5m         |0.6671342638145107|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.015945479133236
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |71-BPMessentia       |3.4725087225498465|
# |69-BPM               |2.5201131974181346|
# |40-SpectralEntropystd|2.2104918465421983|
# |5-SpectralSpreadm    |1.604205115360906 |
# |24-ChromaVector3m    |1.54479612841825  |
# |42-SpectralRolloffstd|1.4707118807356976|
# |49-MFCCs7std         |1.3813535379493267|
# |34-ChromaDeviationm  |1.368546287403156 |
# |44-MFCCs2std         |1.330611879974817 |
# |28-ChromaVector7m    |1.3064827121322973|
# |16-MFCCs8m           |1.2153290141456339|
# |65-ChromaVector10std |1.2080093255628548|
# |46-MFCCs4std         |1.0693355160195424|
# |29-ChromaVector8m    |0.7827009407787631|
# |3-EnergyEntropym     |0.7817197550375354|
# |9-MFCCs1m            |0.7506811144617697|
# |62-ChromaVector7std  |0.7428673007230883|
# |11-MFCCs3m           |0.6950345317168115|
# |45-MFCCs3std         |0.6455433229696865|
# |68-ChromaDeviationstd|0.6101326945833417|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.384073161385375
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |3-EnergyEntropym      |3.972341185463316 |
# |36-Energystd          |2.3334205968594417|
# |51-MFCCs9std          |2.2085709410261827|
# |12-MFCCs4m            |1.9480088543316092|
# |63-ChromaVector8std   |1.8059568895620037|
# |52-MFCCs10std         |1.5348703865067705|
# |55-MFCCs13std         |1.4506501973983588|
# |17-MFCCs9m            |1.4448825884738417|
# |60-ChromaVector5std   |1.3456002950995727|
# |38-SpectralCentroidstd|1.328811024876025 |
# |53-MFCCs11std         |1.2337515424328769|
# |39-SpectralSpreadstd  |1.2181699597747788|
# |25-ChromaVector4m     |1.1873902181303309|
# |10-MFCCs2m            |1.0317881935754443|
# |22-ChromaVector1m     |0.9625589048611967|
# |40-SpectralEntropystd |0.9345543302246417|
# |9-MFCCs1m             |0.7060179952805306|
# |50-MFCCs8std          |0.6925951457000151|
# |44-MFCCs2std          |0.6787747314966025|
# |42-SpectralRolloffstd |0.5755440936935718|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -0.7348624700222487
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |29-ChromaVector8m     |3.7766039058329093|
# |70-BPMconf            |2.8834741824965247|
# |10-MFCCs2m            |2.5017184012458   |
# |38-SpectralCentroidstd|2.1496322968349526|
# |23-ChromaVector2m     |2.1039322611926647|
# |55-MFCCs13std         |1.9351770939584914|
# |11-MFCCs3m            |1.772182120380386 |
# |33-ChromaVector12m    |1.75524680849321  |
# |36-Energystd          |1.4821693274830807|
# |67-ChromaVector12std  |1.3953248416891895|
# |16-MFCCs8m            |1.1758219952257596|
# |35-ZCRstd             |1.1353200126713305|
# |53-MFCCs11std         |1.1222787434877168|
# |64-ChromaVector9std   |1.1189701176660956|
# |30-ChromaVector9m     |1.0914409431618657|
# |71-BPMessentia        |1.0803678602436528|
# |58-ChromaVector3std   |1.0368461036506733|
# |34-ChromaDeviationm   |0.9988513937077349|
# |27-ChromaVector6m     |0.9097170032635566|
# |22-ChromaVector1m     |0.8483820712845924|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.037970624056194
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |5-SpectralSpreadm    |4.247542035489987 |
# |2-Energym            |4.2059527534896   |
# |43-MFCCs1std         |3.3631103271914093|
# |59-ChromaVector4std  |2.685556847414041 |
# |69-BPM               |2.4946539170166364|
# |42-SpectralRolloffstd|2.247954954500442 |
# |4-SpectralCentroidm  |2.0784493732354457|
# |20-MFCCs12m          |1.6804679329064915|
# |10-MFCCs2m           |1.6212541597857189|
# |23-ChromaVector2m    |1.5978640725672464|
# |40-SpectralEntropystd|1.449733902556846 |
# |60-ChromaVector5std  |1.2487501671041492|
# |14-MFCCs6m           |1.244784595878367 |
# |24-ChromaVector3m    |1.2125358965684725|
# |11-MFCCs3m           |1.0323934184037424|
# |48-MFCCs6std         |0.99213063989287  |
# |9-MFCCs1m            |0.9770663580386122|
# |44-MFCCs2std         |0.9417175856731128|
# |34-ChromaDeviationm  |0.7679083991003852|
# |66-ChromaVector11std |0.733482155342711 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -8.756280268064069
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |69-BPM               |3.802395212490911 |
# |13-MFCCs5m           |3.5731360033108364|
# |24-ChromaVector3m    |3.2114232840731463|
# |34-ChromaDeviationm  |2.977334804418076 |
# |29-ChromaVector8m    |2.0435948651857085|
# |45-MFCCs3std         |1.9728654660320566|
# |47-MFCCs5std         |1.8808850096340801|
# |36-Energystd         |1.8111445646418913|
# |3-EnergyEntropym     |1.7359048780981976|
# |8-SpectralRolloffm   |1.657134472413721 |
# |25-ChromaVector4m    |1.352041153560402 |
# |4-SpectralCentroidm  |1.2824577971236502|
# |16-MFCCs8m           |1.25052952370691  |
# |27-ChromaVector6m    |1.2282970611280555|
# |59-ChromaVector4std  |1.0056112568266486|
# |68-ChromaDeviationstd|1.0015123386859057|
# |30-ChromaVector9m    |0.9230976184544831|
# |53-MFCCs11std        |0.8503481618431158|
# |20-MFCCs12m          |0.8323615398595624|
# |12-MFCCs4m           |0.82090574087428  |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.551388153797341
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |9-MFCCs1m          |3.86138065452754  |
# |43-MFCCs1std       |3.2800017735353437|
# |71-BPMessentia     |2.5535120253232035|
# |22-ChromaVector1m  |2.160909159503891 |
# |51-MFCCs9std       |2.078578829631786 |
# |2-Energym          |2.067637126867299 |
# |30-ChromaVector9m  |1.6321956124831698|
# |31-ChromaVector10m |1.5540350146457937|
# |11-MFCCs3m         |1.473785659838843 |
# |12-MFCCs4m         |1.4700380569963991|
# |46-MFCCs4std       |1.4068958040002115|
# |6-SpectralEntropym |1.250577169105923 |
# |18-MFCCs10m        |1.1943223535758052|
# |57-ChromaVector2std|0.9494838487175594|
# |52-MFCCs10std      |0.7518614538346156|
# |19-MFCCs11m        |0.7269832604072043|
# |37-EnergyEntropystd|0.7071812477826545|
# |16-MFCCs8m         |0.6936741980860504|
# |3-EnergyEntropym   |0.6600911686822931|
# |64-ChromaVector9std|0.6018644495396258|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  6.3243620497653374
# Top 20 Coefficients:
# +---------------------+-------------------+
# |feature              |coeff              |
# +---------------------+-------------------+
# |10-MFCCs2m           |1.9034167754885143 |
# |26-ChromaVector5m    |1.6544398699765226 |
# |69-BPM               |1.494881261149833  |
# |37-EnergyEntropystd  |1.3185861468827524 |
# |41-SpectralFluxstd   |1.097143882652935  |
# |18-MFCCs10m          |1.0141542050735473 |
# |54-MFCCs12std        |0.9945760060961744 |
# |44-MFCCs2std         |0.8694359097799014 |
# |32-ChromaVector11m   |0.8631722619632489 |
# |52-MFCCs10std        |0.8616356047563765 |
# |68-ChromaDeviationstd|0.8484414077456787 |
# |33-ChromaVector12m   |0.5876955587632549 |
# |48-MFCCs6std         |0.5829391548553596 |
# |55-MFCCs13std        |0.5415453623754453 |
# |28-ChromaVector7m    |0.5130785823366696 |
# |16-MFCCs8m           |0.5117067398098515 |
# |15-MFCCs7m           |0.4821156976719273 |
# |36-Energystd         |0.46798038576021045|
# |30-ChromaVector9m    |0.4577690295229899 |
# |62-ChromaVector7std  |0.42590476835735525|
# +---------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.011538197724538
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |11-MFCCs3m           |3.4330956717641317|
# |63-ChromaVector8std  |3.0989806207759942|
# |62-ChromaVector7std  |2.211430978397537 |
# |48-MFCCs6std         |2.1039696340591303|
# |55-MFCCs13std        |2.076446613688771 |
# |64-ChromaVector9std  |1.9779539869678053|
# |68-ChromaDeviationstd|1.8089924303284557|
# |26-ChromaVector5m    |1.7448562475839904|
# |36-Energystd         |1.6566557566314852|
# |65-ChromaVector10std |1.5874667210328626|
# |40-SpectralEntropystd|1.5108642821214644|
# |12-MFCCs4m           |1.4104309708073477|
# |60-ChromaVector5std  |1.4075291243278643|
# |46-MFCCs4std         |1.3418819890654312|
# |43-MFCCs1std         |1.2792605463771942|
# |10-MFCCs2m           |1.1799359841389276|
# |17-MFCCs9m           |1.1516363871804454|
# |67-ChromaVector12std |1.1308438709012678|
# |19-MFCCs11m          |1.1092098537317756|
# |49-MFCCs7std         |1.0737182454331078|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.973935057037915
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |9-MFCCs1m             |4.413035001581183 |
# |3-EnergyEntropym      |4.380227504986709 |
# |71-BPMessentia        |2.4740682199139763|
# |54-MFCCs12std         |1.976960657591968 |
# |41-SpectralFluxstd    |1.8175760555656333|
# |58-ChromaVector3std   |1.6325320568316732|
# |38-SpectralCentroidstd|1.5912985616026118|
# |63-ChromaVector8std   |1.5837999582819162|
# |43-MFCCs1std          |1.4977904531970592|
# |36-Energystd          |1.40181177321569  |
# |62-ChromaVector7std   |1.3885606931575234|
# |61-ChromaVector6std   |1.2816541121710368|
# |17-MFCCs9m            |1.21822562111105  |
# |60-ChromaVector5std   |1.1943874118686453|
# |44-MFCCs2std          |1.1385033566565033|
# |42-SpectralRolloffstd |1.0967433039811578|
# |67-ChromaVector12std  |0.9055130239367134|
# |57-ChromaVector2std   |0.8493738071128988|
# |23-ChromaVector2m     |0.7852231722934245|
# |40-SpectralEntropystd |0.7503958805028573|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.61669364437814
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |56-ChromaVector1std |4.631882799102451 |
# |9-MFCCs1m           |3.075502848058194 |
# |69-BPM              |2.2940762970570896|
# |18-MFCCs10m         |1.7539902215329157|
# |45-MFCCs3std        |1.6114888616664245|
# |26-ChromaVector5m   |1.5231672334806017|
# |62-ChromaVector7std |1.463449188240189 |
# |21-MFCCs13m         |1.367078384517128 |
# |48-MFCCs6std        |1.3452083168725644|
# |52-MFCCs10std       |1.3083651258446416|
# |50-MFCCs8std        |1.270690003285663 |
# |13-MFCCs5m          |1.178408314507959 |
# |49-MFCCs7std        |1.1712696786999544|
# |41-SpectralFluxstd  |1.0129269309175755|
# |66-ChromaVector11std|0.9967535112746698|
# |43-MFCCs1std        |0.9841161104548368|
# |59-ChromaVector4std |0.9078608550369358|
# |35-ZCRstd           |0.8999430686881058|
# |58-ChromaVector3std |0.889021547981267 |
# |23-ChromaVector2m   |0.803537012103553 |
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.790505564226972
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |70-BPMconf           |6.232050205232145 |
# |2-Energym            |2.6319439484177902|
# |63-ChromaVector8std  |2.6082466841860956|
# |67-ChromaVector12std |2.5109407548164917|
# |9-MFCCs1m            |1.936664769140959 |
# |71-BPMessentia       |1.8914235769133259|
# |3-EnergyEntropym     |1.7420973754677083|
# |69-BPM               |1.5990728704667991|
# |13-MFCCs5m           |1.5277510633048317|
# |48-MFCCs6std         |1.5094724920999487|
# |25-ChromaVector4m    |1.311830903211639 |
# |52-MFCCs10std        |1.2745084353282696|
# |68-ChromaDeviationstd|1.2639739104270264|
# |46-MFCCs4std         |1.1488413254867158|
# |59-ChromaVector4std  |1.1228597048991487|
# |16-MFCCs8m           |1.0145876863855152|
# |14-MFCCs6m           |0.9910863163236178|
# |58-ChromaVector3std  |0.9649831168525896|
# |28-ChromaVector7m    |0.8989788846855322|
# |61-ChromaVector6std  |0.7164710008748179|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  7.190116535019857
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |13-MFCCs5m            |4.0069630480003005|
# |2-Energym             |3.3445698780660673|
# |70-BPMconf            |2.7434894729986206|
# |7-SpectralFluxm       |2.260784474835555 |
# |30-ChromaVector9m     |2.1026429944181526|
# |45-MFCCs3std          |1.8886786862519005|
# |38-SpectralCentroidstd|1.5669056464380067|
# |1-ZCRm                |1.5169388990710713|
# |28-ChromaVector7m     |1.3860182589121266|
# |15-MFCCs7m            |1.2479784500724926|
# |21-MFCCs13m           |0.9205156085617573|
# |56-ChromaVector1std   |0.8516080455463587|
# |71-BPMessentia        |0.7801203204526904|
# |44-MFCCs2std          |0.7386269391763199|
# |66-ChromaVector11std  |0.6942485025399656|
# |4-SpectralCentroidm   |0.587954573915287 |
# |12-MFCCs4m            |0.5284243601247357|
# |46-MFCCs4std          |0.4704050774857298|
# |35-ZCRstd             |0.2766753508349693|
# |29-ChromaVector8m     |0.2710180163685781|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.9768582447390113
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |44-MFCCs2std        |3.7266230463870746|
# |55-MFCCs13std       |3.148096196908756 |
# |69-BPM              |3.095429818105702 |
# |27-ChromaVector6m   |2.820576224301851 |
# |63-ChromaVector8std |2.183862018561372 |
# |54-MFCCs12std       |2.163404650329754 |
# |34-ChromaDeviationm |2.1596414889933806|
# |3-EnergyEntropym    |2.158907661319753 |
# |36-Energystd        |2.111296888087865 |
# |18-MFCCs10m         |1.2406718280706355|
# |48-MFCCs6std        |1.2219741759514362|
# |2-Energym           |1.0650588815788056|
# |6-SpectralEntropym  |0.8486857837760307|
# |46-MFCCs4std        |0.8452385543990647|
# |24-ChromaVector3m   |0.6485865820431359|
# |52-MFCCs10std       |0.6322728358954877|
# |13-MFCCs5m          |0.619777344267837 |
# |39-SpectralSpreadstd|0.5833496058648374|
# |14-MFCCs6m          |0.578565239669501 |
# |49-MFCCs7std        |0.5675606474443184|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.443985307856733
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |57-ChromaVector2std   |3.1787198594793096|
# |11-MFCCs3m            |3.069589148049915 |
# |43-MFCCs1std          |2.445187718450052 |
# |71-BPMessentia        |2.1860188781154783|
# |35-ZCRstd             |2.1688349425301534|
# |46-MFCCs4std          |2.122475083267476 |
# |63-ChromaVector8std   |2.102557102542936 |
# |53-MFCCs11std         |1.7164630971048696|
# |38-SpectralCentroidstd|1.6532014074132788|
# |17-MFCCs9m            |1.4106703723948693|
# |54-MFCCs12std         |1.3165958869503889|
# |40-SpectralEntropystd |1.2375864539258532|
# |3-EnergyEntropym      |0.9968626817414761|
# |36-Energystd          |0.9507101810452468|
# |1-ZCRm                |0.8755973264098295|
# |64-ChromaVector9std   |0.8590373447336548|
# |59-ChromaVector4std   |0.8546037676568188|
# |25-ChromaVector4m     |0.8399508333407504|
# |14-MFCCs6m            |0.770027465652513 |
# |20-MFCCs12m           |0.7197281652801123|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.919393414368996
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |23-ChromaVector2m    |2.8925054578457203|
# |39-SpectralSpreadstd |2.3328047273274155|
# |36-Energystd         |2.2964225450411124|
# |37-EnergyEntropystd  |2.261449108131416 |
# |32-ChromaVector11m   |2.1921495063763565|
# |68-ChromaDeviationstd|2.1020631662177363|
# |60-ChromaVector5std  |1.9832226895675427|
# |49-MFCCs7std         |1.782735144581411 |
# |58-ChromaVector3std  |1.7298485032843762|
# |5-SpectralSpreadm    |1.728729189129694 |
# |18-MFCCs10m          |1.6081764757860841|
# |11-MFCCs3m           |1.508086469840098 |
# |20-MFCCs12m          |1.26327408680982  |
# |54-MFCCs12std        |1.2136013281473532|
# |53-MFCCs11std        |1.0196146037244889|
# |15-MFCCs7m           |1.0138923298056834|
# |9-MFCCs1m            |1.0017810840561203|
# |25-ChromaVector4m    |0.9462633861658651|
# |31-ChromaVector10m   |0.8361143309781319|
# |61-ChromaVector6std  |0.8067596583557943|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -0.8309081254246724
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |43-MFCCs1std          |4.957837861599466 |
# |41-SpectralFluxstd    |3.099077725703898 |
# |29-ChromaVector8m     |3.050961998208426 |
# |7-SpectralFluxm       |2.9137015630380896|
# |33-ChromaVector12m    |2.0366769863674827|
# |71-BPMessentia        |1.952683130553944 |
# |38-SpectralCentroidstd|1.6930832313567916|
# |58-ChromaVector3std   |1.578825666293818 |
# |39-SpectralSpreadstd  |1.5659475697926666|
# |25-ChromaVector4m     |1.416554018865613 |
# |27-ChromaVector6m     |1.318490362888895 |
# |45-MFCCs3std          |1.1488116286991361|
# |15-MFCCs7m            |1.1461806486811847|
# |28-ChromaVector7m     |1.1122679287535882|
# |47-MFCCs5std          |1.0355846011391738|
# |32-ChromaVector11m    |1.004900231720016 |
# |48-MFCCs6std          |0.9706166598123221|
# |21-MFCCs13m           |0.9560373132469813|
# |42-SpectralRolloffstd |0.9212876602658391|
# |59-ChromaVector4std   |0.8510933825464563|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.011448280379601
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |10-MFCCs2m            |2.6923219022649234|
# |41-SpectralFluxstd    |1.9818595529524954|
# |17-MFCCs9m            |1.9280746264457627|
# |32-ChromaVector11m    |1.859054922626489 |
# |38-SpectralCentroidstd|1.7549843532191944|
# |20-MFCCs12m           |1.7287380625299786|
# |29-ChromaVector8m     |1.7057983044854015|
# |36-Energystd          |1.6826966883826586|
# |70-BPMconf            |1.4091476441589628|
# |26-ChromaVector5m     |1.395039476119383 |
# |51-MFCCs9std          |1.367414005565695 |
# |27-ChromaVector6m     |1.3346944866045944|
# |31-ChromaVector10m    |1.292707999367374 |
# |42-SpectralRolloffstd |1.0694246150181368|
# |40-SpectralEntropystd |1.0344770593933874|
# |65-ChromaVector10std  |1.0223280906582968|
# |25-ChromaVector4m     |0.9465233444643549|
# |71-BPMessentia        |0.9207125876657549|
# |64-ChromaVector9std   |0.8897599773352034|
# |57-ChromaVector2std   |0.874224394385943 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  1.5640330745482813
# Top 20 Coefficients:
# +---------------------+-------------------+
# |feature              |coeff              |
# +---------------------+-------------------+
# |71-BPMessentia       |6.984880058281715  |
# |9-MFCCs1m            |2.947289511239803  |
# |7-SpectralFluxm      |2.894764874601762  |
# |69-BPM               |2.8242078074113808 |
# |41-SpectralFluxstd   |2.7154459301571863 |
# |62-ChromaVector7std  |2.642826636411614  |
# |68-ChromaDeviationstd|2.5317063707440197 |
# |29-ChromaVector8m    |2.237858475863409  |
# |66-ChromaVector11std |1.8661032068864938 |
# |31-ChromaVector10m   |1.70967678400714   |
# |57-ChromaVector2std  |1.4758339840392234 |
# |67-ChromaVector12std |1.402081345939511  |
# |23-ChromaVector2m    |1.3877973684379061 |
# |49-MFCCs7std         |1.0637444992868421 |
# |63-ChromaVector8std  |0.9608034274113245 |
# |27-ChromaVector6m    |0.8755863021740403 |
# |36-Energystd         |0.8051236208534451 |
# |14-MFCCs6m           |0.7763589915822934 |
# |17-MFCCs9m           |0.6567684150242683 |
# |43-MFCCs1std         |0.39050723320625236|
# +---------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.596935015682683
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |59-ChromaVector4std  |4.3191780632176755|
# |47-MFCCs5std         |3.637496359506926 |
# |45-MFCCs3std         |2.636123190718148 |
# |54-MFCCs12std        |2.588508629900052 |
# |66-ChromaVector11std |2.2713362045995296|
# |55-MFCCs13std        |2.1590637283791674|
# |63-ChromaVector8std  |2.088468849654544 |
# |39-SpectralSpreadstd |1.8227100817942945|
# |16-MFCCs8m           |1.5014348126466397|
# |68-ChromaDeviationstd|1.3861637705641117|
# |20-MFCCs12m          |1.2419089172928088|
# |27-ChromaVector6m    |1.2374907078476822|
# |49-MFCCs7std         |1.1564328882020074|
# |34-ChromaDeviationm  |1.1278738138230258|
# |53-MFCCs11std        |1.034288757702923 |
# |35-ZCRstd            |0.94844872826718  |
# |37-EnergyEntropystd  |0.8559487755977153|
# |25-ChromaVector4m    |0.8311363718221534|
# |28-ChromaVector7m    |0.818109383255904 |
# |14-MFCCs6m           |0.7753708707083664|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.2791180971055645
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |23-ChromaVector2m     |2.7700457628214687|
# |67-ChromaVector12std  |2.747997887974174 |
# |43-MFCCs1std          |2.6072293163240396|
# |11-MFCCs3m            |2.370849184509424 |
# |71-BPMessentia        |2.1010127550954323|
# |41-SpectralFluxstd    |1.9993676756200485|
# |35-ZCRstd             |1.9968280930120483|
# |15-MFCCs7m            |1.5224799710159278|
# |42-SpectralRolloffstd |1.329448911061085 |
# |47-MFCCs5std          |1.322576752399254 |
# |38-SpectralCentroidstd|1.2852656942718343|
# |13-MFCCs5m            |1.2732529329496687|
# |12-MFCCs4m            |1.150378236555362 |
# |44-MFCCs2std          |1.0508915820393483|
# |37-EnergyEntropystd   |1.009428843433784 |
# |51-MFCCs9std          |0.9290499002090249|
# |45-MFCCs3std          |0.9185116760593931|
# |56-ChromaVector1std   |0.8779292229348162|
# |33-ChromaVector12m    |0.7703049260143897|
# |60-ChromaVector5std   |0.6132433476172863|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.619959558247498
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |21-MFCCs13m           |2.753345323867884 |
# |22-ChromaVector1m     |2.068195051580475 |
# |41-SpectralFluxstd    |2.057662732753049 |
# |59-ChromaVector4std   |2.032457916848922 |
# |33-ChromaVector12m    |1.8278636097599066|
# |44-MFCCs2std          |1.826593028224027 |
# |18-MFCCs10m           |1.6778159373936519|
# |36-Energystd          |1.6458689587707431|
# |29-ChromaVector8m     |1.587822596580996 |
# |71-BPMessentia        |1.586216853356482 |
# |55-MFCCs13std         |1.558457725180953 |
# |65-ChromaVector10std  |1.5475036976396443|
# |14-MFCCs6m            |1.5467009178881543|
# |38-SpectralCentroidstd|1.4980095478502629|
# |56-ChromaVector1std   |1.381178220578457 |
# |9-MFCCs1m             |1.368983506274598 |
# |23-ChromaVector2m     |1.3608989810346945|
# |19-MFCCs11m           |1.3059284893875536|
# |30-ChromaVector9m     |1.2481225592031568|
# |25-ChromaVector4m     |1.0352849669476705|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.245544287690552
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |19-MFCCs11m         |2.393251137814715 |
# |23-ChromaVector2m   |2.132062265920174 |
# |5-SpectralSpreadm   |2.0639302375653004|
# |71-BPMessentia      |1.92087457706817  |
# |20-MFCCs12m         |1.7488646757718036|
# |66-ChromaVector11std|1.5641571508036163|
# |59-ChromaVector4std |1.5539002957748707|
# |31-ChromaVector10m  |1.5422822543397963|
# |41-SpectralFluxstd  |1.5276901874222013|
# |56-ChromaVector1std |1.4996342641887026|
# |3-EnergyEntropym    |1.49002568640052  |
# |21-MFCCs13m         |1.392570890577138 |
# |62-ChromaVector7std |1.358900876291799 |
# |60-ChromaVector5std |1.2061586113106626|
# |9-MFCCs1m           |1.2021697146660388|
# |25-ChromaVector4m   |1.1559810332526028|
# |4-SpectralCentroidm |1.1034679858816328|
# |7-SpectralFluxm     |0.8153853447116546|
# |1-ZCRm              |0.7123479353602933|
# |28-ChromaVector7m   |0.6445586831224939|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# LinearSVC  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# RandomForestClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +----------------------+--------------------+
# |feature               |score               |
# +----------------------+--------------------+
# |71-BPMessentia        |0.08041925367545144 |
# |69-BPM                |0.05435996802118119 |
# |70-BPMconf            |0.03195174884165693 |
# |39-SpectralSpreadstd  |0.025414249989665648|
# |1-ZCRm                |0.02431922094883485 |
# |2-Energym             |0.022871874215443937|
# |54-MFCCs12std         |0.022269073675018583|
# |3-EnergyEntropym      |0.02170989562125061 |
# |47-MFCCs5std          |0.018378660880899157|
# |55-MFCCs13std         |0.017856572844793688|
# |43-MFCCs1std          |0.017763774996560518|
# |52-MFCCs10std         |0.01766126273320757 |
# |53-MFCCs11std         |0.01758724756296299 |
# |10-MFCCs2m            |0.017546913875359258|
# |49-MFCCs7std          |0.017229298369126074|
# |4-SpectralCentroidm   |0.01720780641980124 |
# |38-SpectralCentroidstd|0.017068546065488282|
# |44-MFCCs2std          |0.016908689664643827|
# |48-MFCCs6std          |0.01619259959579637 |
# |7-SpectralFluxm       |0.016097470068393464|
# +----------------------+--------------------+
# only showing top 20 rows
#
# None
# GBTClassifier  could not be used because PySpark currently only accepts binary classification data for this algorithm
#
# DecisionTreeClassifier  Top 20 Feature Importances
# (Scores add up to 1)
# Lowest score is the least important
#
# +---------------------+---------------------+
# |feature              |score                |
# +---------------------+---------------------+
# |71-BPMessentia       |0.41529211317825343  |
# |7-SpectralFluxm      |0.08762321914415759  |
# |70-BPMconf           |0.07273269630869625  |
# |52-MFCCs10std        |0.0720533844506823   |
# |2-Energym            |0.06091680716663286  |
# |48-MFCCs6std         |0.05780775242510212  |
# |9-MFCCs1m            |0.052767348488626784 |
# |1-ZCRm               |0.049102456328715294 |
# |43-MFCCs1std         |0.024113614912315954 |
# |4-SpectralCentroidm  |0.023933487855856427 |
# |46-MFCCs4std         |0.020956005210823116 |
# |24-ChromaVector3m    |0.017155934447133363 |
# |40-SpectralEntropystd|0.0161677964596312   |
# |37-EnergyEntropystd  |0.011826718291753828 |
# |45-MFCCs3std         |0.0066266697047593125|
# |60-ChromaVector5std  |0.006413688991355836 |
# |13-MFCCs5m           |0.004510306635504398 |
# |30-ChromaVector9m    |0.0                  |
# |23-ChromaVector2m    |0.0                  |
# |31-ChromaVector10m   |0.0                  |
# +---------------------+---------------------+
# only showing top 20 rows
#
# None
#
# MultilayerPerceptronClassifier
# Model Weights:  12023
#
# !!!!!Final Results!!!!!!!!
# +------------------------------+------+
# |Classifier                    |Result|
# +------------------------------+------+
# |LogisticRegression            |39.84 |
# |OneVsRest                     |45.27 |
# |LinearSVC                     |N/A   |
# |NaiveBayes                    |33.33 |
# |RandomForestClassifier        |47.75 |
# |GBTClassifier                 |N/A   |
# |DecisionTreeClassifier        |36.12 |
# |MultilayerPerceptronClassifier|43.72 |
# +------------------------------+------+

# %% [markdown]
# ## Test 3: Feature Selection

# %%
from pyspark.ml.feature import VectorSlicer
from pyspark.ml.feature import ChiSqSelector
from pyspark.ml.linalg import Vectors

classifiers = [OneVsRest()] 

#Select the top n features and view results
maximum = len(input_columns)
for n in range(10,maximum,10):
    print("Testing top n = ",n," features")
    
    # For Tree classifiers
#     best_n_features = RF_featureimportances.argsort()[-n:][::-1]
#     best_n_features= best_n_features.tolist() # convert to a list
#     vs = VectorSlicer(inputCol="features", outputCol="best_features", indices=best_n_features)
#     bestFeaturesDf = vs.transform(test2_data)

    # For Logistic regression or One vs Rest
    selector = ChiSqSelector(numTopFeatures=n, featuresCol="features",
                         outputCol="selectedFeatures", labelCol="label")
    bestFeaturesDf = selector.fit(test2_data).transform(test2_data)
    bestFeaturesDf = bestFeaturesDf.select("label","selectedFeatures")
    bestFeaturesDf = bestFeaturesDf.withColumnRenamed("selectedFeatures","features")

    # Collect features
    features = bestFeaturesDf.select(['features']).collect()

    # Split
    train,test = bestFeaturesDf.randomSplit([0.7,0.3])
    
    # Specify folds
    folds = 2

    #set up your results table
    columns = ['Classifier', 'Result']
    vals = [("Place Holder","N/A")]
    results = spark.createDataFrame(vals, columns)

    for classifier in classifiers:
        new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
        results = results.union(new_result)
    results = results.where("Classifier!='Place Holder'")
    results.show(100,False)
# Out:
# Testing top n =  10  features
#
# OneVsRest
# Intercept:  -4.487672346776169
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |3.683439265649151  |
# |10-MFCCs2m         |1.9337872121180415 |
# |8-SpectralRolloffm |1.2557424320998343 |
# |2-Energym          |0.9840711570584602 |
# |7-SpectralFluxm    |0.46893029689142207|
# |4-SpectralCentroidm|-0.900565781031107 |
# |3-EnergyEntropym   |-1.765073953687721 |
# |5-SpectralSpreadm  |-3.24020794863662  |
# |9-MFCCs1m          |-3.6455050272759015|
# |6-SpectralEntropym |-6.988124806794963 |
# +-------------------+-------------------+
#
# None
# Intercept:  -7.031825249250782
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |9-MFCCs1m          |4.702880903787596   |
# |10-MFCCs2m         |2.95679190776706    |
# |7-SpectralFluxm    |1.762199557741096   |
# |8-SpectralRolloffm |0.8052621408626418  |
# |5-SpectralSpreadm  |0.5500132808306893  |
# |1-ZCRm             |0.2681551827605725  |
# |6-SpectralEntropym |-0.29933440245901   |
# |2-Energym          |-0.33265041186553923|
# |3-EnergyEntropym   |-0.37944222987438725|
# |4-SpectralCentroidm|-1.0425059843111104 |
# +-------------------+--------------------+
#
# None
# Intercept:  -2.020297473379298
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |7-SpectralFluxm    |3.6135150712210455   |
# |1-ZCRm             |2.681411613084564    |
# |4-SpectralCentroidm|0.5395464356813534   |
# |8-SpectralRolloffm |-0.009048970311629758|
# |6-SpectralEntropym |-0.47180422824304324 |
# |10-MFCCs2m         |-1.0952332861335465  |
# |3-EnergyEntropym   |-1.3942224692123306  |
# |5-SpectralSpreadm  |-1.6713355544300554  |
# |2-Energym          |-2.453853665977689   |
# |9-MFCCs1m          |-5.028823047765812   |
# +-------------------+---------------------+
#
# None
# Intercept:  0.985413081135337
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |6-SpectralEntropym |2.0291946634240987 |
# |8-SpectralRolloffm |1.3025920088238634 |
# |4-SpectralCentroidm|0.9112548476519471 |
# |10-MFCCs2m         |0.3470682046399393 |
# |7-SpectralFluxm    |0.16816846257998813|
# |3-EnergyEntropym   |-0.4734813474669118|
# |5-SpectralSpreadm  |-0.518866939498216 |
# |1-ZCRm             |-1.716280311785943 |
# |2-Energym          |-3.111204843018096 |
# |9-MFCCs1m          |-6.102723591459659 |
# +-------------------+-------------------+
#
# None
# Intercept:  -0.7499377922224197
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |8-SpectralRolloffm |3.709105338134824  |
# |9-MFCCs1m          |1.8301025372071646 |
# |2-Energym          |1.1876419796854467 |
# |3-EnergyEntropym   |0.3717371295428259 |
# |1-ZCRm             |0.06017752344849096|
# |5-SpectralSpreadm  |-0.8020397837644406|
# |4-SpectralCentroidm|-1.8689285769712278|
# |7-SpectralFluxm    |-2.3381964151707932|
# |6-SpectralEntropym |-4.1484023979515285|
# |10-MFCCs2m         |-8.847681764239415 |
# +-------------------+-------------------+
#
# None
# Intercept:  -11.419734006947063
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |8-SpectralRolloffm |5.250043721144146  |
# |9-MFCCs1m          |5.146694530160401  |
# |1-ZCRm             |3.6637118205914136 |
# |2-Energym          |2.9824774459329273 |
# |7-SpectralFluxm    |2.4714016029679    |
# |3-EnergyEntropym   |0.07222813865215692|
# |10-MFCCs2m         |0.01932983459816714|
# |5-SpectralSpreadm  |-0.850710130851166 |
# |4-SpectralCentroidm|-1.365653126677206 |
# |6-SpectralEntropym |-5.931642113141841 |
# +-------------------+-------------------+
#
# None
# Intercept:  -5.622093491422157
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |3.7384443628396347 |
# |10-MFCCs2m         |2.3603832130925704 |
# |8-SpectralRolloffm |1.4581445335691912 |
# |7-SpectralFluxm    |0.25729092536437276|
# |5-SpectralSpreadm  |0.1883445276198242 |
# |9-MFCCs1m          |-0.2871700401034201|
# |2-Energym          |-0.6448782641789225|
# |4-SpectralCentroidm|-1.0472109388988633|
# |3-EnergyEntropym   |-1.8974896524435054|
# |6-SpectralEntropym |-4.693208479568833 |
# +-------------------+-------------------+
#
# None
# Intercept:  3.0446930163946866
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |6-SpectralEntropym |1.8083826607976472  |
# |9-MFCCs1m          |1.296013244556039   |
# |4-SpectralCentroidm|-0.11600781959146796|
# |5-SpectralSpreadm  |-0.8218351870803683 |
# |3-EnergyEntropym   |-1.0902383661682753 |
# |7-SpectralFluxm    |-1.231375616928145  |
# |2-Energym          |-2.272784039461443  |
# |8-SpectralRolloffm |-2.722009747319315  |
# |10-MFCCs2m         |-2.796899517010851  |
# |1-ZCRm             |-3.461482981619345  |
# +-------------------+--------------------+
#
# None
# Intercept:  -0.2907654241287498
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |7-SpectralFluxm    |4.162099804656776  |
# |5-SpectralSpreadm  |2.021459814337798  |
# |2-Energym          |1.3916482081292603 |
# |10-MFCCs2m         |-1.2970490217517843|
# |9-MFCCs1m          |-1.5166294930744695|
# |3-EnergyEntropym   |-1.5367291059056596|
# |4-SpectralCentroidm|-1.809864861823994 |
# |1-ZCRm             |-2.948421103702131 |
# |8-SpectralRolloffm |-3.3896854852833367|
# |6-SpectralEntropym |-5.105363330219209 |
# +-------------------+-------------------+
#
# None
# Intercept:  -5.964043977610912
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |5.176504011761103  |
# |6-SpectralEntropym |1.7840401558476073 |
# |10-MFCCs2m         |1.659331784595296  |
# |7-SpectralFluxm    |1.4860080970669491 |
# |4-SpectralCentroidm|0.9164083336690758 |
# |5-SpectralSpreadm  |0.5117074735777769 |
# |8-SpectralRolloffm |0.3926794325094271 |
# |3-EnergyEntropym   |-0.8492466309437178|
# |2-Energym          |-2.1138728716173225|
# |9-MFCCs1m          |-4.272190128583116 |
# +-------------------+-------------------+
#
# None
# Intercept:  -4.660305540568917
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |7-SpectralFluxm    |3.548739764711818   |
# |9-MFCCs1m          |2.8286103592609426  |
# |2-Energym          |1.6605318272277618  |
# |5-SpectralSpreadm  |0.8515409249756902  |
# |8-SpectralRolloffm |0.5953793705112775  |
# |6-SpectralEntropym |0.5133067766230118  |
# |1-ZCRm             |0.09307688413842509 |
# |4-SpectralCentroidm|-0.44823371056676636|
# |3-EnergyEntropym   |-1.3368376918410583 |
# |10-MFCCs2m         |-4.064817956733512  |
# +-------------------+--------------------+
#
# None
# Intercept:  -7.794527556118537
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |1-ZCRm             |4.985798040813621   |
# |10-MFCCs2m         |2.6268219180411667  |
# |2-Energym          |1.677865625203109   |
# |9-MFCCs1m          |1.6707787378478696  |
# |8-SpectralRolloffm |0.1545734335029393  |
# |7-SpectralFluxm    |-0.36869665170809796|
# |3-EnergyEntropym   |-0.8587819149886993 |
# |4-SpectralCentroidm|-1.150871661256273  |
# |5-SpectralSpreadm  |-3.338136223074855  |
# |6-SpectralEntropym |-7.905783680994611  |
# +-------------------+--------------------+
#
# None
# Intercept:  -1.0385244479807432
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |2-Energym          |3.8664319475711224 |
# |10-MFCCs2m         |2.6108097437336624 |
# |3-EnergyEntropym   |2.4698201007381297 |
# |6-SpectralEntropym |0.2786304994526757 |
# |8-SpectralRolloffm |-1.391903990630239 |
# |9-MFCCs1m          |-1.8391610525079332|
# |4-SpectralCentroidm|-1.9687697209611243|
# |1-ZCRm             |-3.4438234750215955|
# |5-SpectralSpreadm  |-3.5914554115913933|
# |7-SpectralFluxm    |-7.102417862618676 |
# +-------------------+-------------------+
#
# None
# Intercept:  -9.378689575090512
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |9-MFCCs1m          |4.17797043262139    |
# |1-ZCRm             |3.8256779202480016  |
# |8-SpectralRolloffm |3.7879377888071666  |
# |7-SpectralFluxm    |3.156980987732192   |
# |4-SpectralCentroidm|1.6397506608593382  |
# |2-Energym          |-0.06401856605565351|
# |5-SpectralSpreadm  |-0.35908511605182053|
# |3-EnergyEntropym   |-0.6820398688810168 |
# |10-MFCCs2m         |-0.8677431284590189 |
# |6-SpectralEntropym |-2.2417979395549485 |
# +-------------------+--------------------+
#
# None
# Intercept:  -3.4699125629221403
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |5-SpectralSpreadm  |2.4503170037961546 |
# |7-SpectralFluxm    |1.8828852108287308 |
# |10-MFCCs2m         |1.6933112612654766 |
# |1-ZCRm             |0.8442087309570834 |
# |8-SpectralRolloffm |0.33402877465464675|
# |3-EnergyEntropym   |-0.1708793016989909|
# |2-Energym          |-0.3398533686880707|
# |6-SpectralEntropym |-1.0641086592748163|
# |4-SpectralCentroidm|-1.2462538730018804|
# |9-MFCCs1m          |-5.9959319648278955|
# +-------------------+-------------------+
#
# None
# Intercept:  -0.3670059130385388
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |5-SpectralSpreadm  |2.8985291773962922  |
# |3-EnergyEntropym   |0.8862344331817888  |
# |8-SpectralRolloffm |0.5079815824859557  |
# |7-SpectralFluxm    |0.4906331984806624  |
# |10-MFCCs2m         |-0.03841249420677303|
# |4-SpectralCentroidm|-0.8326101824305084 |
# |9-MFCCs1m          |-1.7403766672777365 |
# |2-Energym          |-1.753945019493967  |
# |1-ZCRm             |-3.2517377757365167 |
# |6-SpectralEntropym |-3.7998768847022277 |
# +-------------------+--------------------+
#
# None
# Intercept:  -3.367697518137456
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |6-SpectralEntropym |8.155518681082787    |
# |3-EnergyEntropym   |1.937129609926457    |
# |5-SpectralSpreadm  |1.9212305853369704   |
# |10-MFCCs2m         |1.5674529007775757   |
# |4-SpectralCentroidm|1.1718493214449683   |
# |2-Energym          |0.8769934066760544   |
# |8-SpectralRolloffm |-0.027533812028635044|
# |7-SpectralFluxm    |-2.5799946918178325  |
# |9-MFCCs1m          |-3.232449696907184   |
# |1-ZCRm             |-3.6597220217951003  |
# +-------------------+---------------------+
#
# None
# Intercept:  0.08366408050618031
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |4-SpectralCentroidm|2.1856645633515353  |
# |3-EnergyEntropym   |1.3244477439263564  |
# |6-SpectralEntropym |0.6112838840482209  |
# |2-Energym          |0.35454885933953356 |
# |10-MFCCs2m         |-0.08389981838286141|
# |8-SpectralRolloffm |-0.19448552833022426|
# |1-ZCRm             |-1.748616029298437  |
# |7-SpectralFluxm    |-2.579550109344977  |
# |5-SpectralSpreadm  |-2.86840226623429   |
# |9-MFCCs1m          |-4.565577346630884  |
# +-------------------+--------------------+
#
# None
# Intercept:  -5.632183373176186
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |10-MFCCs2m         |9.778963860888945  |
# |6-SpectralEntropym |6.26935413349256   |
# |9-MFCCs1m          |3.554527436552625  |
# |4-SpectralCentroidm|0.5369000837517411 |
# |3-EnergyEntropym   |-0.2689416885239094|
# |1-ZCRm             |-1.3046929874817863|
# |2-Energym          |-1.7132974509591659|
# |5-SpectralSpreadm  |-1.8626272469277219|
# |8-SpectralRolloffm |-2.0891950063828246|
# |7-SpectralFluxm    |-6.197910367720369 |
# +-------------------+-------------------+
#
# None
# Intercept:  -5.207581069593455
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |7-SpectralFluxm    |5.720003251158092  |
# |9-MFCCs1m          |1.549415432988673  |
# |3-EnergyEntropym   |1.544729434159491  |
# |4-SpectralCentroidm|1.3385443546223472 |
# |5-SpectralSpreadm  |1.325989210002457  |
# |2-Energym          |0.798355872796863  |
# |8-SpectralRolloffm |0.18691961338999682|
# |1-ZCRm             |-1.441754516157827 |
# |10-MFCCs2m         |-2.991711016593529 |
# |6-SpectralEntropym |-3.5772741507535857|
# +-------------------+-------------------+
#
# None
# Intercept:  -2.0829714806222484
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |5-SpectralSpreadm  |4.258874465279098   |
# |2-Energym          |2.695758812801663   |
# |10-MFCCs2m         |0.6432704905248053  |
# |1-ZCRm             |0.20429222267038524 |
# |6-SpectralEntropym |-0.04921403189796418|
# |3-EnergyEntropym   |-1.410115281758235  |
# |8-SpectralRolloffm |-1.417643296780315  |
# |7-SpectralFluxm    |-1.9077884761806478 |
# |4-SpectralCentroidm|-2.6592455755864655 |
# |9-MFCCs1m          |-5.925911690647842  |
# +-------------------+--------------------+
#
# None
# Intercept:  1.1627832703497296
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |6-SpectralEntropym |2.4932866128816116  |
# |3-EnergyEntropym   |1.3363257595960583  |
# |10-MFCCs2m         |0.7499865566000011  |
# |5-SpectralSpreadm  |-0.14893545702429278|
# |8-SpectralRolloffm |-0.8940762903952864 |
# |4-SpectralCentroidm|-0.9190757608357044 |
# |1-ZCRm             |-1.5512635106397086 |
# |2-Energym          |-1.562733586262402  |
# |9-MFCCs1m          |-4.351287545341341  |
# |7-SpectralFluxm    |-5.178594289067717  |
# +-------------------+--------------------+
#
# None
# Intercept:  -3.7843854603034424
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |4.160041196748851  |
# |10-MFCCs2m         |2.2794463273811507 |
# |3-EnergyEntropym   |2.2139454759459616 |
# |4-SpectralCentroidm|0.9500970941438054 |
# |9-MFCCs1m          |-0.8407912852637868|
# |2-Energym          |-1.1156975358165853|
# |6-SpectralEntropym |-3.9178668111855894|
# |8-SpectralRolloffm |-4.782956067586654 |
# |7-SpectralFluxm    |-5.007200562493726 |
# |5-SpectralSpreadm  |-5.327506146437361 |
# +-------------------+-------------------+
#
# None
# +----------+------+
# |Classifier|Result|
# +----------+------+
# |OneVsRest |28.98 |
# +----------+------+
#
# Testing top n =  20  features
#
# OneVsRest
# Intercept:  -4.149065108321986
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |3.7201635762310623 |
# |20-MFCCs12m        |2.4331669364983615 |
# |15-MFCCs7m         |2.248318965409276  |
# |12-MFCCs4m         |1.4069173726082604 |
# |17-MFCCs9m         |1.1152400811081797 |
# |13-MFCCs5m         |0.7523072531096555 |
# |14-MFCCs6m         |0.64941740759487   |
# |3-EnergyEntropym   |0.11463779322593604|
# |16-MFCCs8m         |-0.752084154226351 |
# |5-SpectralSpreadm  |-0.8134702984348817|
# |18-MFCCs10m        |-0.8196209469563652|
# |11-MFCCs3m         |-0.8347129932780939|
# |6-SpectralEntropym |-0.9587299633678507|
# |4-SpectralCentroidm|-1.3139199308835363|
# |10-MFCCs2m         |-1.4657314026454658|
# |9-MFCCs1m          |-1.533478639041116 |
# |7-SpectralFluxm    |-1.9234979856982561|
# |19-MFCCs11m        |-2.9238636697469937|
# |8-SpectralRolloffm |-3.5300802173481642|
# |2-Energym          |-4.751516025235651 |
# +-------------------+-------------------+
#
# None
# Intercept:  -8.604852911860066
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |19-MFCCs11m        |5.33550868374151     |
# |20-MFCCs12m        |3.0948923297518673   |
# |18-MFCCs10m        |2.4629999522483623   |
# |10-MFCCs2m         |1.976984376753211    |
# |9-MFCCs1m          |1.6192219643316583   |
# |11-MFCCs3m         |1.432921358300833    |
# |13-MFCCs5m         |0.8910306958558457   |
# |6-SpectralEntropym |0.7733649072593438   |
# |1-ZCRm             |0.5048731448963008   |
# |7-SpectralFluxm    |0.46145056367373005  |
# |8-SpectralRolloffm |0.09641641949802873  |
# |4-SpectralCentroidm|-0.042392461449758764|
# |3-EnergyEntropym   |-0.05243703985977981 |
# |12-MFCCs4m         |-0.4901897196067527  |
# |16-MFCCs8m         |-1.123349193722697   |
# |2-Energym          |-1.3122298489222415  |
# |15-MFCCs7m         |-1.3914421634199412  |
# |17-MFCCs9m         |-1.5917648959237083  |
# |14-MFCCs6m         |-2.5708646993993867  |
# |5-SpectralSpreadm  |-2.901207510415824   |
# +-------------------+---------------------+
#
# None
# Intercept:  -4.144646106050828
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |12-MFCCs4m         |3.151490993891898   |
# |13-MFCCs5m         |2.758421619990745   |
# |1-ZCRm             |2.655238273498576   |
# |9-MFCCs1m          |0.855882395565747   |
# |6-SpectralEntropym |0.588865086299153   |
# |5-SpectralSpreadm  |0.5374418263544116  |
# |16-MFCCs8m         |0.48025859649235575 |
# |17-MFCCs9m         |0.46263024976986067 |
# |10-MFCCs2m         |0.23058280687062715 |
# |8-SpectralRolloffm |0.04696431630541617 |
# |14-MFCCs6m         |-0.0621942775269257 |
# |3-EnergyEntropym   |-0.35307243161780305|
# |15-MFCCs7m         |-0.4111061306214449 |
# |11-MFCCs3m         |-0.6327672540263087 |
# |2-Energym          |-0.7346608998362579 |
# |18-MFCCs10m        |-0.9094347900850832 |
# |20-MFCCs12m        |-0.9407006271764123 |
# |4-SpectralCentroidm|-1.5885921438631496 |
# |7-SpectralFluxm    |-2.0284987050971104 |
# |19-MFCCs11m        |-4.572827406358226  |
# +-------------------+--------------------+
#
# None
# Intercept:  -0.07127389173895422
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |16-MFCCs8m         |2.9393555862983396  |
# |15-MFCCs7m         |2.3297179291975727  |
# |2-Energym          |1.6623767020501954  |
# |6-SpectralEntropym |1.6085433414147774  |
# |14-MFCCs6m         |1.4664855636178322  |
# |13-MFCCs5m         |1.2955769027514445  |
# |17-MFCCs9m         |1.2395279976192053  |
# |20-MFCCs12m        |0.890795681267696   |
# |9-MFCCs1m          |0.3048429838909242  |
# |18-MFCCs10m        |0.10474218368815302 |
# |5-SpectralSpreadm  |-0.12218984699151078|
# |12-MFCCs4m         |-0.1859167523880524 |
# |8-SpectralRolloffm |-0.3085238411608903 |
# |4-SpectralCentroidm|-0.36526097723915846|
# |11-MFCCs3m         |-0.9443912737692656 |
# |7-SpectralFluxm    |-1.280439587594771  |
# |10-MFCCs2m         |-1.5649535597683273 |
# |1-ZCRm             |-2.3290633969699677 |
# |3-EnergyEntropym   |-3.5425300803512974 |
# |19-MFCCs11m        |-4.656544918585301  |
# +-------------------+--------------------+
#
# None
# Intercept:  -1.8265591397059058
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |9-MFCCs1m          |3.869875482080872  |
# |15-MFCCs7m         |3.2654977688908176 |
# |19-MFCCs11m        |2.8725631747420004 |
# |16-MFCCs8m         |2.8231926453618796 |
# |11-MFCCs3m         |1.615173425115384  |
# |4-SpectralCentroidm|1.4181166220990142 |
# |3-EnergyEntropym   |0.8226557681458915 |
# |5-SpectralSpreadm  |0.5230091888387258 |
# |14-MFCCs6m         |-0.2216521452469577|
# |1-ZCRm             |-0.5462276224366219|
# |18-MFCCs10m        |-0.5466514273215419|
# |17-MFCCs9m         |-0.972169567454399 |
# |7-SpectralFluxm    |-1.1193493176730045|
# |6-SpectralEntropym |-1.1974374596133373|
# |2-Energym          |-1.473662826897705 |
# |12-MFCCs4m         |-2.0676470281744566|
# |13-MFCCs5m         |-2.3336364281334343|
# |10-MFCCs2m         |-2.420658379334484 |
# |8-SpectralRolloffm |-4.132282085127129 |
# |20-MFCCs12m        |-8.326141896941001 |
# +-------------------+-------------------+
#
# None
# Intercept:  -9.563767517405081
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |15-MFCCs7m         |3.9399512479518277  |
# |19-MFCCs11m        |3.7998977372686347  |
# |3-EnergyEntropym   |3.2295653505566566  |
# |1-ZCRm             |2.6724007362909448  |
# |12-MFCCs4m         |2.2532239279503576  |
# |18-MFCCs10m        |1.935127482504393   |
# |10-MFCCs2m         |1.8956468280362853  |
# |11-MFCCs3m         |1.4401455820202342  |
# |9-MFCCs1m          |1.1500953426708487  |
# |6-SpectralEntropym |0.48854503144805983 |
# |4-SpectralCentroidm|0.1329537518841112  |
# |5-SpectralSpreadm  |-0.47933613891530424|
# |17-MFCCs9m         |-0.53551291560074   |
# |13-MFCCs5m         |-1.3619884500292787 |
# |7-SpectralFluxm    |-1.633261223583747  |
# |20-MFCCs12m        |-1.8507395092901484 |
# |14-MFCCs6m         |-2.0798051615325948 |
# |8-SpectralRolloffm |-3.105023839624515  |
# |16-MFCCs8m         |-4.157318476629923  |
# |2-Energym          |-6.055972800447637  |
# +-------------------+--------------------+
#
# None
# Intercept:  -4.788725339919755
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |1-ZCRm             |3.275858241029884    |
# |20-MFCCs12m        |2.5457204185641444   |
# |10-MFCCs2m         |1.84715809583697     |
# |7-SpectralFluxm    |1.4990147746143638   |
# |15-MFCCs7m         |1.2188289211884982   |
# |12-MFCCs4m         |0.40233367646716833  |
# |18-MFCCs10m        |0.30139184552084414  |
# |14-MFCCs6m         |0.04421078380813066  |
# |3-EnergyEntropym   |-0.052483744602027434|
# |11-MFCCs3m         |-0.10446089209069369 |
# |17-MFCCs9m         |-0.19934673180596846 |
# |9-MFCCs1m          |-0.43497356501943385 |
# |6-SpectralEntropym |-1.0069526674850895  |
# |19-MFCCs11m        |-1.2404399240839281  |
# |13-MFCCs5m         |-1.3280618306916838  |
# |8-SpectralRolloffm |-1.3520851101429114  |
# |4-SpectralCentroidm|-1.583204685291609   |
# |16-MFCCs8m         |-1.7862496607593528  |
# |5-SpectralSpreadm  |-2.8090697258609607  |
# |2-Energym          |-4.880087724993533   |
# +-------------------+---------------------+
#
# None
# Intercept:  4.787974748970874
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |11-MFCCs3m         |1.807171441176585   |
# |16-MFCCs8m         |1.2635745720703062  |
# |8-SpectralRolloffm |1.2205757542119855  |
# |5-SpectralSpreadm  |1.1380498427550563  |
# |19-MFCCs11m        |1.0355618362891692  |
# |14-MFCCs6m         |0.8397305652116391  |
# |18-MFCCs10m        |0.4339488905398233  |
# |7-SpectralFluxm    |0.2728978691641252  |
# |6-SpectralEntropym |-0.07134717945442219|
# |2-Energym          |-0.23464815597310063|
# |13-MFCCs5m         |-0.39905916805200564|
# |12-MFCCs4m         |-0.7798720922526238 |
# |17-MFCCs9m         |-0.786004395239021  |
# |4-SpectralCentroidm|-1.5660892665747457 |
# |10-MFCCs2m         |-1.8762043956541703 |
# |3-EnergyEntropym   |-2.353619214918245  |
# |15-MFCCs7m         |-2.5272625265759596 |
# |20-MFCCs12m        |-3.0637037072972837 |
# |1-ZCRm             |-3.6896661781797233 |
# |9-MFCCs1m          |-5.05446851538963   |
# +-------------------+--------------------+
#
# None
# Intercept:  -4.074669488149858
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |16-MFCCs8m         |3.1548728379473006  |
# |3-EnergyEntropym   |2.448346689649021   |
# |13-MFCCs5m         |2.4290845240631485  |
# |14-MFCCs6m         |1.8746783675932317  |
# |17-MFCCs9m         |1.85227957223959    |
# |11-MFCCs3m         |1.752005901597148   |
# |12-MFCCs4m         |1.5821965593164942  |
# |9-MFCCs1m          |1.3995044654144075  |
# |18-MFCCs10m        |0.7102591225038238  |
# |7-SpectralFluxm    |0.6187557603843089  |
# |5-SpectralSpreadm  |0.5974321166219068  |
# |10-MFCCs2m         |0.010375098506886924|
# |4-SpectralCentroidm|-0.20121648302097192|
# |20-MFCCs12m        |-0.36688086925992697|
# |19-MFCCs11m        |-0.8071077495012704 |
# |6-SpectralEntropym |-2.0574601534727885 |
# |15-MFCCs7m         |-2.213618951961471  |
# |2-Energym          |-3.144338456545242  |
# |8-SpectralRolloffm |-3.826784089107044  |
# |1-ZCRm             |-4.172625143113335  |
# +-------------------+--------------------+
#
# None
# Intercept:  -8.28855227159753
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |5.885410537192185  |
# |10-MFCCs2m         |2.521509668987965  |
# |20-MFCCs12m        |2.3197413285596764 |
# |8-SpectralRolloffm |2.245731907362172  |
# |13-MFCCs5m         |1.4933484616794082 |
# |9-MFCCs1m          |1.3184229918566814 |
# |6-SpectralEntropym |1.1575315125233803 |
# |16-MFCCs8m         |1.0123727461335783 |
# |12-MFCCs4m         |0.9934833635767805 |
# |15-MFCCs7m         |0.7249218880022102 |
# |4-SpectralCentroidm|0.5309721495894834 |
# |5-SpectralSpreadm  |0.34445213426542154|
# |17-MFCCs9m         |0.24217413047572434|
# |18-MFCCs10m        |0.08582363553827824|
# |7-SpectralFluxm    |-0.4568401181852057|
# |14-MFCCs6m         |-0.6700669117298882|
# |2-Energym          |-1.132189391159354 |
# |11-MFCCs3m         |-1.6053590024333466|
# |3-EnergyEntropym   |-2.9824979338992277|
# |19-MFCCs11m        |-4.39710980408212  |
# +-------------------+-------------------+
#
# None
# Intercept:  -6.65529146786205
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |14-MFCCs6m         |4.436710527127969   |
# |12-MFCCs4m         |3.0622330194725556  |
# |19-MFCCs11m        |2.7542068429666933  |
# |3-EnergyEntropym   |2.118857360805834   |
# |11-MFCCs3m         |1.6273092949809325  |
# |4-SpectralCentroidm|1.3271180759358856  |
# |8-SpectralRolloffm |0.951589839733944   |
# |15-MFCCs7m         |0.9494218790287848  |
# |18-MFCCs10m        |0.8483829679282048  |
# |13-MFCCs5m         |0.47793892748974226 |
# |9-MFCCs1m          |0.20462317123224935 |
# |7-SpectralFluxm    |-0.23019037305181872|
# |5-SpectralSpreadm  |-0.38878451747490794|
# |16-MFCCs8m         |-0.43578138411762973|
# |6-SpectralEntropym |-0.6269151748270196 |
# |10-MFCCs2m         |-0.6947101950407887 |
# |1-ZCRm             |-0.7657905504279519 |
# |17-MFCCs9m         |-1.5613590306102996 |
# |2-Energym          |-2.220725810094586  |
# |20-MFCCs12m        |-3.9183775333098203 |
# +-------------------+--------------------+
#
# None
# Intercept:  -6.691949208564428
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |4.620513421226697  |
# |18-MFCCs10m        |2.6533405377322437 |
# |11-MFCCs3m         |2.421314213110079  |
# |20-MFCCs12m        |2.2996620926243603 |
# |3-EnergyEntropym   |1.6516321683375725 |
# |19-MFCCs11m        |1.609839369764601  |
# |5-SpectralSpreadm  |1.2908568638515958 |
# |17-MFCCs9m         |0.7961438347364623 |
# |10-MFCCs2m         |0.03065305789772786|
# |12-MFCCs4m         |-0.556147302202637 |
# |16-MFCCs8m         |-1.0092957172041521|
# |15-MFCCs7m         |-1.0288323504066539|
# |4-SpectralCentroidm|-1.2909078967876682|
# |6-SpectralEntropym |-1.414897902672686 |
# |14-MFCCs6m         |-1.7547436801021414|
# |9-MFCCs1m          |-1.7637928929287978|
# |13-MFCCs5m         |-2.0119616342336135|
# |7-SpectralFluxm    |-2.804717337648538 |
# |2-Energym          |-3.7639312724710066|
# |8-SpectralRolloffm |-6.52972989685497  |
# +-------------------+-------------------+
#
# None
# Intercept:  3.2949798612553334
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |2-Energym          |3.6234929344000335  |
# |3-EnergyEntropym   |3.252274699708598   |
# |20-MFCCs12m        |1.9207152455050218  |
# |9-MFCCs1m          |0.7031733306583176  |
# |4-SpectralCentroidm|0.7002101061588727  |
# |10-MFCCs2m         |-0.45080233051903296|
# |7-SpectralFluxm    |-0.9670921189684865 |
# |15-MFCCs7m         |-1.400402247345501  |
# |14-MFCCs6m         |-1.7087621603945546 |
# |19-MFCCs11m        |-1.8383563285102842 |
# |6-SpectralEntropym |-1.8479493413033448 |
# |17-MFCCs9m         |-2.2540322362069904 |
# |8-SpectralRolloffm |-2.3337251260989516 |
# |1-ZCRm             |-2.5075466329204588 |
# |11-MFCCs3m         |-3.084758964600856  |
# |12-MFCCs4m         |-3.164577097386629  |
# |5-SpectralSpreadm  |-3.1843227731127572 |
# |18-MFCCs10m        |-4.53508799555973   |
# |16-MFCCs8m         |-4.917309144591416  |
# |13-MFCCs5m         |-5.057854445042219  |
# +-------------------+--------------------+
#
# None
# Intercept:  -7.6024733188399924
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |19-MFCCs11m        |4.518537881855485    |
# |1-ZCRm             |3.4472416940997483   |
# |13-MFCCs5m         |3.2070475580472837   |
# |11-MFCCs3m         |2.5989324159046      |
# |15-MFCCs7m         |2.4653611099769153   |
# |6-SpectralEntropym |1.9893471553102047   |
# |10-MFCCs2m         |1.6918000250493344   |
# |12-MFCCs4m         |0.3427428130775744   |
# |17-MFCCs9m         |0.08444238730540297  |
# |16-MFCCs8m         |-0.049670524366978275|
# |7-SpectralFluxm    |-0.14166868769248045 |
# |8-SpectralRolloffm |-0.2059083861482859  |
# |3-EnergyEntropym   |-0.29431183416936707 |
# |18-MFCCs10m        |-0.9042277266252124  |
# |9-MFCCs1m          |-1.0224578508035767  |
# |20-MFCCs12m        |-1.0245435196470536  |
# |4-SpectralCentroidm|-1.8720446359125151  |
# |2-Energym          |-3.3965897142415358  |
# |5-SpectralSpreadm  |-4.057903817243513   |
# |14-MFCCs6m         |-4.371415155606248   |
# +-------------------+---------------------+
#
# None
# Intercept:  -6.569269025228183
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |9-MFCCs1m          |3.352374341366363   |
# |10-MFCCs2m         |3.0194224365610145  |
# |20-MFCCs12m        |2.644770701752899   |
# |16-MFCCs8m         |2.377471313701744   |
# |13-MFCCs5m         |1.8526345893699359  |
# |17-MFCCs9m         |1.1490978696609868  |
# |5-SpectralSpreadm  |1.0004926767162678  |
# |1-ZCRm             |0.6361326513597128  |
# |3-EnergyEntropym   |0.45933944396242454 |
# |12-MFCCs4m         |0.3062672535168085  |
# |7-SpectralFluxm    |0.2112987612683164  |
# |6-SpectralEntropym |0.0471919660286533  |
# |15-MFCCs7m         |-0.03148531768312614|
# |8-SpectralRolloffm |-0.03953701390551008|
# |4-SpectralCentroidm|-0.23709410902328365|
# |18-MFCCs10m        |-0.3218588860046737 |
# |14-MFCCs6m         |-0.7888960985736287 |
# |11-MFCCs3m         |-0.8163708592313073 |
# |2-Energym          |-1.4089968374369293 |
# |19-MFCCs11m        |-6.269626190518088  |
# +-------------------+--------------------+
#
# None
# Intercept:  -2.0600996661253936
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |7-SpectralFluxm    |3.914513643325739  |
# |16-MFCCs8m         |2.49591572500465   |
# |11-MFCCs3m         |2.470280014370176  |
# |17-MFCCs9m         |2.304016871553271  |
# |18-MFCCs10m        |1.3186055402098775 |
# |13-MFCCs5m         |0.737589169542193  |
# |14-MFCCs6m         |0.6789543611994336 |
# |15-MFCCs7m         |0.5996075308054059 |
# |4-SpectralCentroidm|0.47695895760238155|
# |20-MFCCs12m        |0.3195910768473742 |
# |3-EnergyEntropym   |0.19816518836222755|
# |12-MFCCs4m         |-0.4513941336750111|
# |6-SpectralEntropym |-0.6576238640078662|
# |9-MFCCs1m          |-1.2326645258920939|
# |19-MFCCs11m        |-1.4671912390256026|
# |2-Energym          |-1.8555555984081356|
# |8-SpectralRolloffm |-2.1230899939070906|
# |5-SpectralSpreadm  |-2.4426690443443255|
# |1-ZCRm             |-3.137170943720219 |
# |10-MFCCs2m         |-3.4190296545181713|
# +-------------------+-------------------+
#
# None
# Intercept:  -4.160724940661723
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |8-SpectralRolloffm |6.290340730164621   |
# |2-Energym          |5.276793443949661   |
# |4-SpectralCentroidm|2.615173482806007   |
# |5-SpectralSpreadm  |2.093204020871711   |
# |7-SpectralFluxm    |1.5311562241782797  |
# |10-MFCCs2m         |1.364336877574453   |
# |9-MFCCs1m          |1.275692007395197   |
# |17-MFCCs9m         |1.268017539258627   |
# |20-MFCCs12m        |1.04867370252028    |
# |14-MFCCs6m         |0.5366624988342801  |
# |15-MFCCs7m         |0.28433933492386776 |
# |3-EnergyEntropym   |0.24645455060429897 |
# |6-SpectralEntropym |0.1935588265504989  |
# |11-MFCCs3m         |-0.11766147897583862|
# |12-MFCCs4m         |-0.5238001610044635 |
# |1-ZCRm             |-1.5389743045510857 |
# |16-MFCCs8m         |-1.6314007003594617 |
# |18-MFCCs10m        |-2.5211964179532362 |
# |19-MFCCs11m        |-3.431304831681267  |
# |13-MFCCs5m         |-5.38183917172905   |
# +-------------------+--------------------+
#
# None
# Intercept:  -1.1938315983903913
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |6-SpectralEntropym |2.5593255015813017  |
# |4-SpectralCentroidm|2.2884266146882557  |
# |17-MFCCs9m         |2.0812667972208456  |
# |15-MFCCs7m         |1.7282410357198175  |
# |13-MFCCs5m         |1.4071367712397147  |
# |8-SpectralRolloffm |1.2313226050231003  |
# |14-MFCCs6m         |1.1739948295398763  |
# |3-EnergyEntropym   |1.0145970298479954  |
# |5-SpectralSpreadm  |0.9267963377447063  |
# |2-Energym          |0.628305971045627   |
# |16-MFCCs8m         |0.5499329728982011  |
# |20-MFCCs12m        |0.009122663690295164|
# |12-MFCCs4m         |-0.16040394748574296|
# |9-MFCCs1m          |-0.3320829055818113 |
# |18-MFCCs10m        |-1.406154803245124  |
# |7-SpectralFluxm    |-1.9913102697086638 |
# |1-ZCRm             |-2.228644206753583  |
# |11-MFCCs3m         |-2.800039440758076  |
# |10-MFCCs2m         |-3.2208575632008563 |
# |19-MFCCs11m        |-4.693114580332243  |
# +-------------------+--------------------+
#
# None
# Intercept:  -3.8101874061882888
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |20-MFCCs12m        |8.517748317383187   |
# |8-SpectralRolloffm |2.915952307406558   |
# |19-MFCCs11m        |2.86684666132009    |
# |18-MFCCs10m        |2.8296069978149383  |
# |2-Energym          |2.019190020274551   |
# |6-SpectralEntropym |1.942886423708473   |
# |17-MFCCs9m         |0.9564837308599003  |
# |7-SpectralFluxm    |0.1900573066164808  |
# |1-ZCRm             |-0.25471674411423406|
# |11-MFCCs3m         |-1.0221452196445455 |
# |14-MFCCs6m         |-1.1162693864051938 |
# |4-SpectralCentroidm|-1.1589305504794665 |
# |3-EnergyEntropym   |-1.775068729258134  |
# |5-SpectralSpreadm  |-1.878647903697903  |
# |16-MFCCs8m         |-1.9569004138867925 |
# |9-MFCCs1m          |-2.117010392000153  |
# |10-MFCCs2m         |-2.3263530655641063 |
# |15-MFCCs7m         |-2.745076603230554  |
# |12-MFCCs4m         |-3.255318865751899  |
# |13-MFCCs5m         |-3.7046130687864336 |
# +-------------------+--------------------+
#
# None
# Intercept:  -5.75434544323894
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |13-MFCCs5m         |5.528798264098585  |
# |12-MFCCs4m         |2.8801401409077596 |
# |5-SpectralSpreadm  |2.5981262239953766 |
# |18-MFCCs10m        |2.4921977686721504 |
# |11-MFCCs3m         |1.8438057152271718 |
# |7-SpectralFluxm    |1.3179826208343473 |
# |4-SpectralCentroidm|1.1182540591721886 |
# |10-MFCCs2m         |1.0646285247710097 |
# |19-MFCCs11m        |0.9633193766973404 |
# |3-EnergyEntropym   |0.8956575587153467 |
# |2-Energym          |0.606486958632372  |
# |15-MFCCs7m         |0.16510513423105697|
# |6-SpectralEntropym |0.04522439737671675|
# |17-MFCCs9m         |-1.4432378593632325|
# |14-MFCCs6m         |-1.5982035085511044|
# |1-ZCRm             |-1.8693006892612707|
# |20-MFCCs12m        |-2.8271850926935618|
# |9-MFCCs1m          |-3.2349229411815825|
# |16-MFCCs8m         |-3.380241356547607 |
# |8-SpectralRolloffm |-4.410676722758872 |
# +-------------------+-------------------+
#
# None
# Intercept:  -3.43394674726834
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |9-MFCCs1m          |3.5146871844663616  |
# |8-SpectralRolloffm |2.483533785265413   |
# |7-SpectralFluxm    |1.9394471202408181  |
# |14-MFCCs6m         |1.8500766226213035  |
# |10-MFCCs2m         |1.621265718954135   |
# |5-SpectralSpreadm  |1.4224872625566245  |
# |20-MFCCs12m        |1.3072960204322077  |
# |16-MFCCs8m         |1.116162544931106   |
# |3-EnergyEntropym   |0.752607377715063   |
# |2-Energym          |0.37112162793792386 |
# |1-ZCRm             |0.15439459778202577 |
# |15-MFCCs7m         |-0.20709277966906803|
# |11-MFCCs3m         |-0.4690973686563057 |
# |13-MFCCs5m         |-0.8678205780878323 |
# |4-SpectralCentroidm|-0.9194544318720722 |
# |12-MFCCs4m         |-1.697405380391011  |
# |17-MFCCs9m         |-2.2714669029221173 |
# |18-MFCCs10m        |-2.498884864377102  |
# |6-SpectralEntropym |-3.0486947474977892 |
# |19-MFCCs11m        |-4.352379334769646  |
# +-------------------+--------------------+
#
# None
# Intercept:  1.182380452122636
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |2-Energym          |1.8097127185533948  |
# |8-SpectralRolloffm |0.8336713792849219  |
# |9-MFCCs1m          |0.7629447254426353  |
# |20-MFCCs12m        |0.74526772263817    |
# |5-SpectralSpreadm  |0.7436959514996064  |
# |14-MFCCs6m         |0.6382325865135058  |
# |10-MFCCs2m         |0.5511164574076131  |
# |17-MFCCs9m         |0.501642077115177   |
# |6-SpectralEntropym |-0.19148685643118815|
# |4-SpectralCentroidm|-0.193846517655269  |
# |18-MFCCs10m        |-0.22808963163210813|
# |15-MFCCs7m         |-0.47629405969649974|
# |13-MFCCs5m         |-0.7736003599589173 |
# |3-EnergyEntropym   |-0.8934713028382998 |
# |7-SpectralFluxm    |-1.1442338767141143 |
# |11-MFCCs3m         |-1.4355242320324197 |
# |16-MFCCs8m         |-1.977098223693689  |
# |1-ZCRm             |-2.04870017071242   |
# |19-MFCCs11m        |-3.295227950494762  |
# |12-MFCCs4m         |-3.8369224608145314 |
# +-------------------+--------------------+
#
# None
# Intercept:  -2.477250745782285
# Top 20 Coefficients:
# +-------------------+-------------------+
# |feature            |coeff              |
# +-------------------+-------------------+
# |1-ZCRm             |4.515402286230376  |
# |20-MFCCs12m        |3.0770898930374018 |
# |4-SpectralCentroidm|2.8129442832472793 |
# |5-SpectralSpreadm  |2.361290813663518  |
# |14-MFCCs6m         |1.6568877542927027 |
# |16-MFCCs8m         |0.22604498933218317|
# |6-SpectralEntropym |0.21667951688023068|
# |18-MFCCs10m        |-0.5211098570293853|
# |9-MFCCs1m          |-0.570957680639567 |
# |12-MFCCs4m         |-0.9912745786349878|
# |13-MFCCs5m         |-1.3586164662598457|
# |3-EnergyEntropym   |-1.3869546955256513|
# |17-MFCCs9m         |-2.013701500657392 |
# |19-MFCCs11m        |-2.1534952879871145|
# |2-Energym          |-2.2811694959490723|
# |8-SpectralRolloffm |-2.5591300154919256|
# |15-MFCCs7m         |-3.5056366487517137|
# |7-SpectralFluxm    |-4.166942011801318 |
# |10-MFCCs2m         |-5.386187828539106 |
# |11-MFCCs3m         |-5.776259243421363 |
# +-------------------+-------------------+
#
# None
# +----------+------+
# |Classifier|Result|
# +----------+------+
# |OneVsRest |33.17 |
# +----------+------+
#
# Testing top n =  30  features
#
# OneVsRest
# Intercept:  -2.3620967635551597
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |1-ZCRm             |2.4492200226728786  |
# |22-ChromaVector1m  |2.1484921836545854  |
# |18-MFCCs10m        |1.8704773310104992  |
# |25-ChromaVector4m  |1.8553666631079904  |
# |30-ChromaVector9m  |1.7894321765675993  |
# |4-SpectralCentroidm|1.2104918988358218  |
# |5-SpectralSpreadm  |1.158923923119289   |
# |17-MFCCs9m         |0.9391139721281827  |
# |24-ChromaVector3m  |0.6834687844710723  |
# |26-ChromaVector5m  |0.5703993744948221  |
# |20-MFCCs12m        |0.4675767499554436  |
# |9-MFCCs1m          |0.2261708182274362  |
# |10-MFCCs2m         |-0.1348356339538696 |
# |14-MFCCs6m         |-0.1631978778647864 |
# |23-ChromaVector2m  |-0.26648206011787584|
# |19-MFCCs11m        |-0.29366297661403734|
# |27-ChromaVector6m  |-0.8366190777458873 |
# |11-MFCCs3m         |-0.9515216663617078 |
# |16-MFCCs8m         |-1.0668547768152479 |
# |6-SpectralEntropym |-1.1652371281469762 |
# +-------------------+--------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.564974212164014
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |29-ChromaVector8m  |4.688368376295592    |
# |30-ChromaVector9m  |2.72228308502526     |
# |28-ChromaVector7m  |2.0401575801532643   |
# |15-MFCCs7m         |2.013155182069955    |
# |14-MFCCs6m         |1.759968851424288    |
# |24-ChromaVector3m  |1.6143584562385884   |
# |16-MFCCs8m         |1.6136874393027356   |
# |4-SpectralCentroidm|1.488310664862848    |
# |27-ChromaVector6m  |1.0341572660880707   |
# |1-ZCRm             |0.6401501351917479   |
# |22-ChromaVector1m  |0.1912109425503926   |
# |18-MFCCs10m        |0.09803592401214375  |
# |12-MFCCs4m         |0.04387148909230562  |
# |19-MFCCs11m        |0.012088491620838138 |
# |13-MFCCs5m         |-0.025555559093687282|
# |9-MFCCs1m          |-0.0906494994164312  |
# |26-ChromaVector5m  |-0.4753525062869916  |
# |5-SpectralSpreadm  |-0.5664149814305445  |
# |6-SpectralEntropym |-0.6688294894999054  |
# |17-MFCCs9m         |-0.7049822448396651  |
# +-------------------+---------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.310377798972611
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |1-ZCRm             |3.2776433246520704   |
# |23-ChromaVector2m  |2.113382723598977    |
# |18-MFCCs10m        |2.020293002663638    |
# |17-MFCCs9m         |1.8125840793450585   |
# |19-MFCCs11m        |1.796328122408858    |
# |12-MFCCs4m         |1.7710107631507017   |
# |3-EnergyEntropym   |1.0787855881920227   |
# |21-MFCCs13m        |0.6812415546440472   |
# |8-SpectralRolloffm |0.604529893936471    |
# |25-ChromaVector4m  |0.5793368972872506   |
# |20-MFCCs12m        |0.29921069490891916  |
# |10-MFCCs2m         |-0.026934071533426376|
# |28-ChromaVector7m  |-0.04527586100925856 |
# |14-MFCCs6m         |-0.05012942825624966 |
# |22-ChromaVector1m  |-0.2693677886586245  |
# |24-ChromaVector3m  |-0.34213030239910985 |
# |9-MFCCs1m          |-0.4594406726198851  |
# |16-MFCCs8m         |-0.4799217136541897  |
# |4-SpectralCentroidm|-0.5286999639273375  |
# |13-MFCCs5m         |-0.6487082647682653  |
# +-------------------+---------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.10092067719417
# Top 20 Coefficients:
# +-------------------+---------------------+
# |feature            |coeff                |
# +-------------------+---------------------+
# |3-EnergyEntropym   |5.4582749576587055   |
# |12-MFCCs4m         |2.514494854753556    |
# |23-ChromaVector2m  |2.1108439458688992   |
# |22-ChromaVector1m  |1.7340286648257024   |
# |19-MFCCs11m        |1.6988929042753091   |
# |9-MFCCs1m          |1.594508409342367    |
# |10-MFCCs2m         |1.2327908747845118   |
# |30-ChromaVector9m  |0.939481133958861    |
# |20-MFCCs12m        |0.6035653683334747   |
# |18-MFCCs10m        |0.21373228098198446  |
# |4-SpectralCentroidm|0.17926932338453275  |
# |25-ChromaVector4m  |0.014157223737505603 |
# |13-MFCCs5m         |-0.024128754354001695|
# |11-MFCCs3m         |-0.06839085645492034 |
# |27-ChromaVector6m  |-0.09270376378584695 |
# |17-MFCCs9m         |-0.21073759143331228 |
# |28-ChromaVector7m  |-0.24698822304050527 |
# |16-MFCCs8m         |-0.3882454341567158  |
# |21-MFCCs13m        |-0.42538578557485857 |
# |14-MFCCs6m         |-0.6051550380167425  |
# +-------------------+---------------------+
# only showing top 20 rows
#
# None
# Intercept:  -0.7081590757947088
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |14-MFCCs6m         |3.38868079566132    |
# |22-ChromaVector1m  |2.952752519370458   |
# |4-SpectralCentroidm|2.106989543090842   |
# |29-ChromaVector8m  |1.7207190235058831  |
# |16-MFCCs8m         |1.444837503134339   |
# |3-EnergyEntropym   |1.1799413373176508  |
# |24-ChromaVector3m  |0.8218734848228225  |
# |23-ChromaVector2m  |0.7471753342693876  |
# |27-ChromaVector6m  |0.6544614684387804  |
# |5-SpectralSpreadm  |0.5747134114529676  |
# |25-ChromaVector4m  |0.46785884237977554 |
# |7-SpectralFluxm    |0.23422403453050383 |
# |1-ZCRm             |0.2088206747571779  |
# |8-SpectralRolloffm |-0.22316987232985594|
# |20-MFCCs12m        |-0.42975382466194467|
# |28-ChromaVector7m  |-0.49818661272139897|
# |6-SpectralEntropym |-0.6307684130891811 |
# |15-MFCCs7m         |-0.9211950401190626 |
# |12-MFCCs4m         |-1.0826242990358226 |
# |2-Energym          |-1.1905807977600062 |
# +-------------------+--------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.499915427579479
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |29-ChromaVector8m  |4.58520590752858    |
# |5-SpectralSpreadm  |3.4586568905125814  |
# |22-ChromaVector1m  |3.454608476056749   |
# |1-ZCRm             |2.7463451630575135  |
# |28-ChromaVector7m  |2.296348387988479   |
# |14-MFCCs6m         |1.8736723951855445  |
# |17-MFCCs9m         |1.8168744300316009  |
# |8-SpectralRolloffm |1.0500045418665271  |
# |18-MFCCs10m        |1.046541438731634   |
# |15-MFCCs7m         |1.0057602500104637  |
# |16-MFCCs8m         |0.843684714367746   |
# |9-MFCCs1m          |0.8377021599408889  |
# |26-ChromaVector5m  |0.370378224024673   |
# |4-SpectralCentroidm|0.04572749387916924 |
# |7-SpectralFluxm    |-0.21887884563765164|
# |25-ChromaVector4m  |-0.37037828851413523|
# |19-MFCCs11m        |-0.7641725912125382 |
# |30-ChromaVector9m  |-0.8126509291589846 |
# |13-MFCCs5m         |-1.0274443282230823 |
# |11-MFCCs3m         |-1.278811469370394  |
# +-------------------+--------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.71867789474303
# Top 20 Coefficients:
# +-------------------+--------------------+
# |feature            |coeff               |
# +-------------------+--------------------+
# |1-ZCRm             |2.558612085659796   |
# |4-SpectralCentroidm|2.259908342035262   |
# |30-ChromaVector9m  |2.0007683027428627  |
# |15-MFCCs7m         |1.754850726112884   |
# |17-MFCCs9m         |1.35973935341135    |
# |22-ChromaVector1m  |0.8903585396112595  |
# |11-MFCCs3m         |0.6379121933706238  |
# |18-MFCCs10m        |0.607199878025263   |
# |28-ChromaVector7m  |0.49657123613026816 |
# |21-MFCCs13m        |0.3291102930245792  |
# |13-MFCCs5m         |0.30747767006466625 |
# |20-MFCCs12m        |0.276595303466525   |
# |25-ChromaVector4m  |0.2593637702136151  |
# |10-MFCCs2m         |0.2108676941442973  |
# |9-MFCCs1m          |0.11455386086401244 |
# |5-SpectralSpreadm  |0.06748518066190766 |
# ...
# |49-MFCCs7std         |1.1356366913051221|
# |14-MFCCs6m           |1.0398969411305687|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.822621458230947
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |3-EnergyEntropym      |4.6427096548776925|
# |9-MFCCs1m             |4.055819087180658 |
# |43-MFCCs1std          |2.701552071761176 |
# |63-ChromaVector8std   |2.341970057066952 |
# |70-BPMconf            |2.1868331567666424|
# |55-MFCCs13std         |1.958208711727691 |
# |41-SpectralFluxstd    |1.6779198818401244|
# |40-SpectralEntropystd |1.6436970623421743|
# |57-ChromaVector2std   |1.6366399893651695|
# |2-Energym             |1.5653973984606904|
# |58-ChromaVector3std   |1.4016223890377704|
# |62-ChromaVector7std   |1.3147110859095918|
# |60-ChromaVector5std   |1.2940017987966514|
# |67-ChromaVector12std  |1.2670723742103867|
# |36-Energystd          |1.1568869191538593|
# |38-SpectralCentroidstd|1.1365096792270797|
# |61-ChromaVector6std   |1.0322837848941389|
# |23-ChromaVector2m     |1.019775633954626 |
# |44-MFCCs2std          |0.9533428182087477|
# |54-MFCCs12std         |0.5819188818248947|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.293568991105919
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |56-ChromaVector1std |5.292639883762709 |
# |9-MFCCs1m           |2.893489855284409 |
# |69-BPM              |2.3553756297504593|
# |45-MFCCs3std        |1.6651768644833724|
# |18-MFCCs10m         |1.5131067187120923|
# |50-MFCCs8std        |1.4503978512102953|
# |11-MFCCs3m          |1.4229080171418278|
# |43-MFCCs1std        |1.3994928742459336|
# |62-ChromaVector7std |1.2935907914852178|
# |58-ChromaVector3std |1.2871896315029   |
# |66-ChromaVector11std|1.1137996891397997|
# |48-MFCCs6std        |1.094104895694057 |
# |35-ZCRstd           |1.0614430264685037|
# |41-SpectralFluxstd  |1.0438662208383176|
# |21-MFCCs13m         |0.8671182697846339|
# |27-ChromaVector6m   |0.832564498868251 |
# |49-MFCCs7std        |0.8209463577695522|
# |28-ChromaVector7m   |0.7899904008185423|
# |65-ChromaVector10std|0.7325070734542111|
# |53-MFCCs11std       |0.6968893480787248|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.858455296108158
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |63-ChromaVector8std  |3.291966941270133 |
# |68-ChromaDeviationstd|3.2910759096570406|
# |70-BPMconf           |2.683775195984412 |
# |2-Energym            |2.611944542662581 |
# |67-ChromaVector12std |2.4938088234849367|
# |13-MFCCs5m           |2.4459713800943526|
# |9-MFCCs1m            |2.2496098305129286|
# |52-MFCCs10std        |1.7503743745039266|
# |5-SpectralSpreadm    |1.7277014919170286|
# |48-MFCCs6std         |1.67116602359034  |
# |28-ChromaVector7m    |1.587734663685212 |
# |14-MFCCs6m           |1.4352032831249726|
# |46-MFCCs4std         |1.4080818201098448|
# |69-BPM               |1.2114283920863913|
# |18-MFCCs10m          |1.1708374587773054|
# |26-ChromaVector5m    |1.0330553537627951|
# |25-ChromaVector4m    |1.001019993947794 |
# |3-EnergyEntropym     |0.9886699364480706|
# |1-ZCRm               |0.9817366095489802|
# |58-ChromaVector3std  |0.9656512047419943|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  8.56647226250029
# Top 20 Coefficients:
# +----------------------+-------------------+
# |feature               |coeff              |
# +----------------------+-------------------+
# |2-Energym             |3.9555823136169446 |
# |7-SpectralFluxm       |3.0833073382547322 |
# |13-MFCCs5m            |2.964031108243295  |
# |15-MFCCs7m            |2.0127013530219044 |
# |29-ChromaVector8m     |1.8996066471492408 |
# |45-MFCCs3std          |1.7337601058909928 |
# |38-SpectralCentroidstd|1.66643584856465   |
# |1-ZCRm                |1.4559410936781534 |
# |28-ChromaVector7m     |1.4500299802899486 |
# |70-BPMconf            |1.4262418151216725 |
# |30-ChromaVector9m     |1.250495980841832  |
# |56-ChromaVector1std   |1.1195158429110734 |
# |21-MFCCs13m           |1.112538336960585  |
# |66-ChromaVector11std  |0.6897067072152401 |
# |35-ZCRstd             |0.35072241367685963|
# |12-MFCCs4m            |0.23427231084953418|
# |4-SpectralCentroidm   |0.17309085686862624|
# |19-MFCCs11m           |0.1509193093129481 |
# |62-ChromaVector7std   |0.14559514029131013|
# |47-MFCCs5std          |0.09477559397908795|
# +----------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.056754662074362
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |69-BPM              |4.08434296260916  |
# |44-MFCCs2std        |3.6167445392935216|
# |36-Energystd        |3.0940739934262695|
# |55-MFCCs13std       |2.8164321888464388|
# |27-ChromaVector6m   |2.3242666336491897|
# |54-MFCCs12std       |2.1399815912561406|
# |3-EnergyEntropym    |1.8656786191742627|
# |18-MFCCs10m         |1.6493350993422802|
# |34-ChromaDeviationm |1.4524656648622754|
# |49-MFCCs7std        |1.3056733220590488|
# |14-MFCCs6m          |1.2579648085885162|
# |2-Energym           |1.0542095869010712|
# |6-SpectralEntropym  |0.9864685598231963|
# |53-MFCCs11std       |0.9393249132638196|
# |29-ChromaVector8m   |0.9236420859279658|
# |63-ChromaVector8std |0.8357882860720817|
# |24-ChromaVector3m   |0.7301586512414406|
# |48-MFCCs6std        |0.7214464738654626|
# |52-MFCCs10std       |0.6337754935459532|
# |66-ChromaVector11std|0.5290626314037385|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0793818042090524
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |46-MFCCs4std          |2.5668283543749655|
# |57-ChromaVector2std   |2.2767345878836074|
# |70-BPMconf            |2.2149578917303505|
# |35-ZCRstd             |2.0496764797879377|
# |17-MFCCs9m            |1.9606028067286316|
# |11-MFCCs3m            |1.6519040019813769|
# |43-MFCCs1std          |1.5007282460521993|
# |54-MFCCs12std         |1.479422068132381 |
# |38-SpectralCentroidstd|1.4438533508215914|
# |64-ChromaVector9std   |1.418892401564123 |
# |63-ChromaVector8std   |1.3149169733279047|
# |59-ChromaVector4std   |1.1784911158176794|
# |1-ZCRm                |1.0708148781964206|
# |14-MFCCs6m            |1.0434926167753305|
# |40-SpectralEntropystd |1.0072577715799251|
# |26-ChromaVector5m     |0.9467882159906672|
# |44-MFCCs2std          |0.9088272376325155|
# |21-MFCCs13m           |0.8514596946809295|
# |32-ChromaVector11m    |0.756389597931271 |
# |36-Energystd          |0.6293572895406999|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.237978517284966
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |36-Energystd         |3.05785246906937  |
# |37-EnergyEntropystd  |2.4731335357128867|
# |60-ChromaVector5std  |2.4207595305293697|
# |16-MFCCs8m           |2.393162258030637 |
# |68-ChromaDeviationstd|2.3756811326479093|
# |20-MFCCs12m          |1.924020236602664 |
# |32-ChromaVector11m   |1.5001976529498737|
# |58-ChromaVector3std  |1.473061809471117 |
# |11-MFCCs3m           |1.445910689851854 |
# |23-ChromaVector2m    |1.4429828711399708|
# |54-MFCCs12std        |1.4368168388600115|
# |39-SpectralSpreadstd |1.3702338759063286|
# |18-MFCCs10m          |1.369958090746887 |
# |49-MFCCs7std         |1.2676066473543333|
# |43-MFCCs1std         |1.2274069995347143|
# |5-SpectralSpreadm    |1.0342822971015444|
# |9-MFCCs1m            |1.026566102333813 |
# |53-MFCCs11std        |0.9515997808939748|
# |51-MFCCs9std         |0.929675143460697 |
# |30-ChromaVector9m    |0.9042257022112187|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.2450438939705144
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |41-SpectralFluxstd    |5.114245899089924 |
# |43-MFCCs1std          |4.858883845042732 |
# |7-SpectralFluxm       |4.364499124337327 |
# |29-ChromaVector8m     |2.6316935537644843|
# |21-MFCCs13m           |2.070451631116076 |
# |33-ChromaVector12m    |1.6366387385369798|
# |39-SpectralSpreadstd  |1.566395781228989 |
# |37-EnergyEntropystd   |1.4728647155788328|
# |23-ChromaVector2m     |1.443879288784967 |
# |45-MFCCs3std          |1.3925244713117717|
# |38-SpectralCentroidstd|1.390266671719478 |
# |47-MFCCs5std          |1.2825744542138384|
# |58-ChromaVector3std   |1.1310830189949086|
# |30-ChromaVector9m     |1.1258166419936544|
# |18-MFCCs10m           |1.125303243211265 |
# |25-ChromaVector4m     |1.07963424035416  |
# |59-ChromaVector4std   |1.054129905186914 |
# |70-BPMconf            |1.037662002104941 |
# |15-MFCCs7m            |0.8490389079796244|
# |10-MFCCs2m            |0.7657831702222493|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.384272831645449
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |32-ChromaVector11m    |2.64746059154435  |
# |36-Energystd          |2.439527880723873 |
# |10-MFCCs2m            |2.342714577783784 |
# |41-SpectralFluxstd    |2.272773722038736 |
# |17-MFCCs9m            |2.003640015914595 |
# |12-MFCCs4m            |1.9950219651428653|
# |38-SpectralCentroidstd|1.7622333916280537|
# |21-MFCCs13m           |1.758622960175669 |
# |26-ChromaVector5m     |1.5314985019752678|
# |20-MFCCs12m           |1.5066871985175092|
# |29-ChromaVector8m     |1.3655171190593818|
# |61-ChromaVector6std   |1.3357171415507199|
# |27-ChromaVector6m     |1.335435492865002 |
# |55-MFCCs13std         |1.3291627147477523|
# |39-SpectralSpreadstd  |1.2914303957415008|
# |42-SpectralRolloffstd |1.2583962694031054|
# |58-ChromaVector3std   |1.124545843514974 |
# |54-MFCCs12std         |1.088195433118194 |
# |51-MFCCs9std          |1.0352534463793523|
# |64-ChromaVector9std   |0.9869334878878621|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -0.2573529982053202
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |70-BPMconf           |6.94637796217411  |
# |69-BPM               |3.833798685713259 |
# |41-SpectralFluxstd   |3.7608177065250383|
# |7-SpectralFluxm      |3.523084829393412 |
# |62-ChromaVector7std  |2.8215578253258506|
# |9-MFCCs1m            |2.2498799409326624|
# |67-ChromaVector12std |2.137726639390428 |
# |29-ChromaVector8m    |1.9920200085423365|
# |66-ChromaVector11std |1.6991078267411515|
# |57-ChromaVector2std  |1.626486190183305 |
# |68-ChromaDeviationstd|1.6193536500043382|
# |17-MFCCs9m           |1.6126415681256812|
# |63-ChromaVector8std  |1.2466871111730171|
# |27-ChromaVector6m    |1.0317444700189276|
# |12-MFCCs4m           |0.8821826969322413|
# |31-ChromaVector10m   |0.8737197978183279|
# |23-ChromaVector2m    |0.7278180378818754|
# |49-MFCCs7std         |0.6536772748064474|
# |20-MFCCs12m          |0.6267364640652218|
# |61-ChromaVector6std  |0.395102294489439 |
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.61216450250495
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |47-MFCCs5std         |3.2522478610933137|
# |59-ChromaVector4std  |3.0356109244863307|
# |45-MFCCs3std         |2.6334940277218783|
# |66-ChromaVector11std |2.190665240767558 |
# |69-BPM               |2.04987330740946  |
# |67-ChromaVector12std |1.9981175987751896|
# |55-MFCCs13std        |1.9788825375813452|
# |51-MFCCs9std         |1.957228481055498 |
# |68-ChromaDeviationstd|1.9293928390818724|
# |15-MFCCs7m           |1.8286212642597375|
# |34-ChromaDeviationm  |1.7122167611501864|
# |54-MFCCs12std        |1.6211715897350625|
# |39-SpectralSpreadstd |1.5656404073821995|
# |63-ChromaVector8std  |1.4267668822344206|
# |25-ChromaVector4m    |1.405316829228256 |
# |37-EnergyEntropystd  |1.3994092785787942|
# |32-ChromaVector11m   |1.173082682989145 |
# |50-MFCCs8std         |1.1652066162607855|
# |27-ChromaVector6m    |1.124416430351359 |
# |12-MFCCs4m           |1.0067231113275446|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.1735674237954785
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |43-MFCCs1std          |2.4571840842346564|
# |35-ZCRstd             |2.269628920944361 |
# |15-MFCCs7m            |2.0483825780724327|
# |60-ChromaVector5std   |1.9465117515521428|
# |13-MFCCs5m            |1.9076949706399655|
# |38-SpectralCentroidstd|1.7949452158259955|
# |70-BPMconf            |1.7466718364003258|
# |41-SpectralFluxstd    |1.7108909283003662|
# |25-ChromaVector4m     |1.5974522097638997|
# |10-MFCCs2m            |1.5773495853536572|
# |42-SpectralRolloffstd |1.5148039428667623|
# |44-MFCCs2std          |1.4579243744392913|
# |30-ChromaVector9m     |1.3885152117098645|
# |11-MFCCs3m            |1.319856816321749 |
# |67-ChromaVector12std  |1.2059506243261422|
# |54-MFCCs12std         |1.132391975046909 |
# |56-ChromaVector1std   |0.9482965604642308|
# |45-MFCCs3std          |0.9375208258142497|
# |37-EnergyEntropystd   |0.733774173132241 |
# |3-EnergyEntropym      |0.725804778280011 |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.0833647887365494
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |18-MFCCs10m           |2.5301911343234464|
# |65-ChromaVector10std  |2.381319943770135 |
# |36-Energystd          |1.800380710957646 |
# |22-ChromaVector1m     |1.6827322682635455|
# |44-MFCCs2std          |1.650627734303081 |
# |33-ChromaVector12m    |1.6361208148398512|
# |70-BPMconf            |1.6097452130398373|
# |28-ChromaVector7m     |1.5795554233401214|
# |41-SpectralFluxstd    |1.4135740138510324|
# |19-MFCCs11m           |1.2970584381320704|
# |25-ChromaVector4m     |1.2248249429638887|
# |42-SpectralRolloffstd |1.2155451810145763|
# |29-ChromaVector8m     |1.2145439973052508|
# |55-MFCCs13std         |1.147571883316345 |
# |59-ChromaVector4std   |1.1460517760222884|
# |38-SpectralCentroidstd|1.127313815355592 |
# |14-MFCCs6m            |0.9092171063398097|
# |34-ChromaDeviationm   |0.8444129154812419|
# |61-ChromaVector6std   |0.8343090036759988|
# |32-ChromaVector11m    |0.7460134090785634|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.948058344841006
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |23-ChromaVector2m   |2.30986863486578  |
# |70-BPMconf          |2.2012526766970457|
# |65-ChromaVector10std|2.180627049737617 |
# |5-SpectralSpreadm   |2.15999982309493  |
# |66-ChromaVector11std|2.1310046805308707|
# |19-MFCCs11m         |2.026124958860856 |
# |3-EnergyEntropym    |1.9515363204189398|
# |9-MFCCs1m           |1.855999000469593 |
# |21-MFCCs13m         |1.7694197460242105|
# |41-SpectralFluxstd  |1.684619079328803 |
# |56-ChromaVector1std |1.613689806787814 |
# |62-ChromaVector7std |1.611950538362409 |
# |31-ChromaVector10m  |1.5239208141990261|
# |59-ChromaVector4std |1.373304774153384 |
# |60-ChromaVector5std |1.2645587455888136|
# |33-ChromaVector12m  |1.22097280687692  |
# |4-SpectralCentroidm |1.1001794939216067|
# |20-MFCCs12m         |1.0424219685724616|
# |30-ChromaVector9m   |0.9637527978188781|
# |7-SpectralFluxm     |0.9446166313997861|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# +----------+------+
# |Classifier|Result|
# +----------+------+
# |OneVsRest |43.08 |
# +----------+------+

# %% [markdown]
# ## Train final model

# %%
from pyspark.ml.feature import VectorSlicer
from pyspark.ml.feature import ChiSqSelector
from pyspark.ml.linalg import Vectors

classifiers = [OneVsRest()] 

#Select the top n features and view results
n = 71

# For Logistic regression or One vs Rest
selector = ChiSqSelector(numTopFeatures=n, featuresCol="features",
                     outputCol="selectedFeatures", labelCol="label")
bestFeaturesDf = selector.fit(test2_data).transform(test2_data)
bestFeaturesDf = bestFeaturesDf.select("label","selectedFeatures")
bestFeaturesDf = bestFeaturesDf.withColumnRenamed("selectedFeatures","features")

# Collect features
features = bestFeaturesDf.select(['features']).collect()

# Split
train,test = bestFeaturesDf.randomSplit([0.7,0.3])

# Specify folds
folds = 2

#set up your results table
columns = ['Classifier', 'Result']
vals = [("Place Holder","N/A")]
results = spark.createDataFrame(vals, columns)

for classifier in classifiers:
    new_result = ClassTrainEval(classifier,features,classes,folds,train,test)
    results = results.union(new_result)
results = results.where("Classifier!='Place Holder'")
results.show(100,False)
# Out:
#
# OneVsRest
# Intercept:  -6.580458247144103
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |9-MFCCs1m           |4.002770960508903 |
# |71-BPMessentia      |2.361225791764684 |
# |5-SpectralSpreadm   |2.1711779325755125|
# |18-MFCCs10m         |2.00270061605298  |
# |63-ChromaVector8std |1.7988253632428668|
# |3-EnergyEntropym    |1.6453831224196154|
# |11-MFCCs3m          |1.630045983043709 |
# |52-MFCCs10std       |1.5234453053307606|
# |24-ChromaVector3m   |1.4841467112591167|
# |67-ChromaVector12std|1.348375021269884 |
# |43-MFCCs1std        |1.2333461521940112|
# |2-Energym           |1.1864363735051946|
# |58-ChromaVector3std |0.9937927049682765|
# |36-Energystd        |0.913939346115755 |
# |50-MFCCs8std        |0.8677429106209348|
# |54-MFCCs12std       |0.852871082344563 |
# |12-MFCCs4m          |0.8004373673127889|
# |22-ChromaVector1m   |0.5836641228481052|
# |64-ChromaVector9std |0.5725447451299506|
# |6-SpectralEntropym  |0.5238775795831582|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.9433064139925937
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |71-BPMessentia       |4.606992533539093 |
# |49-MFCCs7std         |2.400576220035489 |
# |40-SpectralEntropystd|2.3054167381553756|
# |69-BPM               |2.271755167208211 |
# |34-ChromaDeviationm  |2.109169952423034 |
# |44-MFCCs2std         |2.024702273853239 |
# |61-ChromaVector6std  |1.8569802272162013|
# |28-ChromaVector7m    |1.827089822001182 |
# |3-EnergyEntropym     |1.7322568313955427|
# |48-MFCCs6std         |1.7032089642675128|
# |65-ChromaVector10std |1.6988032002381108|
# |24-ChromaVector3m    |1.69034520435539  |
# |42-SpectralRolloffstd|1.5575699059562114|
# |54-MFCCs12std        |1.5426072974511056|
# |11-MFCCs3m           |1.4335879128137867|
# |43-MFCCs1std         |1.3035257707502408|
# |46-MFCCs4std         |0.983317444100631 |
# |5-SpectralSpreadm    |0.9013106546007456|
# |66-ChromaVector11std |0.8306896818216125|
# |16-MFCCs8m           |0.8134729589046157|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.971309370576584
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |3-EnergyEntropym      |3.248980827673493 |
# |12-MFCCs4m            |2.418511979563239 |
# |17-MFCCs9m            |2.058052310899195 |
# |67-ChromaVector12std  |1.8518527415884245|
# |36-Energystd          |1.6225184353000313|
# |55-MFCCs13std         |1.5574746823545433|
# |16-MFCCs8m            |1.5430855307578975|
# |52-MFCCs10std         |1.373968684872131 |
# |57-ChromaVector2std   |1.3333393434343255|
# |45-MFCCs3std          |1.2661682810141495|
# |40-SpectralEntropystd |1.2236663497375082|
# |38-SpectralCentroidstd|1.1492524790298568|
# |51-MFCCs9std          |1.1416463163020791|
# |25-ChromaVector4m     |1.0158853091213582|
# |44-MFCCs2std          |0.9872847163701155|
# |53-MFCCs11std         |0.9747536825376459|
# |26-ChromaVector5m     |0.8294024427234445|
# |9-MFCCs1m             |0.8047901328308148|
# |60-ChromaVector5std   |0.7563471836456758|
# |42-SpectralRolloffstd |0.65122085884089  |
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  0.8910705556137185
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |36-Energystd          |3.272325561076738 |
# |29-ChromaVector8m     |2.6481879789956415|
# |33-ChromaVector12m    |2.534626889869221 |
# |70-BPMconf            |2.15703829925866  |
# |38-SpectralCentroidstd|2.1134605710921006|
# |10-MFCCs2m            |2.0888960524716804|
# |53-MFCCs11std         |2.0724035559679295|
# |11-MFCCs3m            |1.73291280052709  |
# |63-ChromaVector8std   |1.5408073240328184|
# |35-ZCRstd             |1.4920549780725065|
# |58-ChromaVector3std   |1.4307450701810212|
# |26-ChromaVector5m     |1.3701922549376488|
# |67-ChromaVector12std  |1.3010934853872866|
# |71-BPMessentia        |1.1584491769527223|
# |27-ChromaVector6m     |1.0426251267648694|
# |47-MFCCs5std          |0.8987110349314569|
# |23-ChromaVector2m     |0.7286984437826464|
# |28-ChromaVector7m     |0.6910979557138419|
# |3-EnergyEntropym      |0.6837561747990101|
# |12-MFCCs4m            |0.6576603304887042|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.111959079676649
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |5-SpectralSpreadm    |3.8386921447559947|
# |2-Energym            |3.7820766375040393|
# |43-MFCCs1std         |2.7264821518844755|
# |59-ChromaVector4std  |2.412910207248053 |
# |69-BPM               |2.326887049105301 |
# |42-SpectralRolloffstd|2.1714566656229515|
# |4-SpectralCentroidm  |1.9165260923104939|
# |10-MFCCs2m           |1.6645686825768553|
# |44-MFCCs2std         |1.5107689106504247|
# |40-SpectralEntropystd|1.4264271808893527|
# |11-MFCCs3m           |1.2751113175211006|
# |24-ChromaVector3m    |1.2025152059601456|
# |66-ChromaVector11std |1.1994490128090136|
# |26-ChromaVector5m    |1.047712060250237 |
# |48-MFCCs6std         |0.9635065074445648|
# |60-ChromaVector5std  |0.9346589490757107|
# |63-ChromaVector8std  |0.8746146524381369|
# |34-ChromaDeviationm  |0.7203227833460799|
# |28-ChromaVector7m    |0.7125394996890916|
# |9-MFCCs1m            |0.6532722769839721|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -8.400647599843527
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |69-BPM               |3.975894648006026 |
# |34-ChromaDeviationm  |3.1537842816683854|
# |45-MFCCs3std         |3.049873223653564 |
# |13-MFCCs5m           |2.89142207800026  |
# |24-ChromaVector3m    |2.7845519173793285|
# |8-SpectralRolloffm   |1.5682922434604774|
# |3-EnergyEntropym     |1.4449283650824263|
# |47-MFCCs5std         |1.4389982413689144|
# |17-MFCCs9m           |1.3775415835860192|
# |68-ChromaDeviationstd|1.3743188610738148|
# |4-SpectralCentroidm  |1.348491042753048 |
# |12-MFCCs4m           |1.3168239164947189|
# |27-ChromaVector6m    |1.2902036763185494|
# |59-ChromaVector4std  |1.0639381930117504|
# |65-ChromaVector10std |0.9898058903506715|
# |44-MFCCs2std         |0.8543270673313892|
# |35-ZCRstd            |0.8518151742609293|
# |20-MFCCs12m          |0.8324900034072237|
# |21-MFCCs13m          |0.8251636835102059|
# |53-MFCCs11std        |0.8143407500115161|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.2081346287022106
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |9-MFCCs1m          |4.3446227979288725|
# |71-BPMessentia     |2.959026547094434 |
# |22-ChromaVector1m  |2.758914444291997 |
# |43-MFCCs1std       |2.587215156435612 |
# |2-Energym          |2.4122508785188566|
# |30-ChromaVector9m  |1.9794872400108057|
# |51-MFCCs9std       |1.8435235924884823|
# |57-ChromaVector2std|1.8339943436194444|
# |12-MFCCs4m         |1.4710500655726346|
# |25-ChromaVector4m  |1.42063870037874  |
# |46-MFCCs4std       |1.251953379956267 |
# |53-MFCCs11std      |1.1310181501452554|
# |41-SpectralFluxstd |0.949300792777491 |
# |37-EnergyEntropystd|0.8578355757371733|
# |29-ChromaVector8m  |0.8167352514379533|
# |11-MFCCs3m         |0.8041397090704562|
# |6-SpectralEntropym |0.7419408054648967|
# |19-MFCCs11m        |0.6896486801261879|
# |63-ChromaVector8std|0.6640501216488632|
# |16-MFCCs8m         |0.5152248694424509|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  9.270085917523366
# Top 20 Coefficients:
# +----------------------+-------------------+
# |feature               |coeff              |
# +----------------------+-------------------+
# |32-ChromaVector11m    |1.5774871545958893 |
# |37-EnergyEntropystd   |1.3785109626236887 |
# |19-MFCCs11m           |1.314437467811161  |
# |68-ChromaDeviationstd |1.2728412671603955 |
# |48-MFCCs6std          |1.2555269249554606 |
# |54-MFCCs12std         |1.206333139730211  |
# |62-ChromaVector7std   |1.2004877004163788 |
# |33-ChromaVector12m    |0.9493238068252677 |
# |69-BPM                |0.9479607531981603 |
# |44-MFCCs2std          |0.8822247824152034 |
# |52-MFCCs10std         |0.8327793681786123 |
# |34-ChromaDeviationm   |0.7219237945299313 |
# |26-ChromaVector5m     |0.6878063282424502 |
# |18-MFCCs10m           |0.6506935601829981 |
# |10-MFCCs2m            |0.6325601707825451 |
# |25-ChromaVector4m     |0.6106435710016719 |
# |23-ChromaVector2m     |0.5693179355596196 |
# |49-MFCCs7std          |0.47402810302211534|
# |38-SpectralCentroidstd|0.46889058275047224|
# |39-SpectralSpreadstd  |0.39201674491294075|
# +----------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -9.95655821094709
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |11-MFCCs3m           |3.31386984998968  |
# |63-ChromaVector8std  |2.8731970013437618|
# |64-ChromaVector9std  |2.281112364507269 |
# |40-SpectralEntropystd|2.241755694569634 |
# |55-MFCCs13std        |2.1849262087638044|
# |19-MFCCs11m          |1.9544263067968628|
# |62-ChromaVector7std  |1.7360939677226548|
# |65-ChromaVector10std |1.734621147848315 |
# |17-MFCCs9m           |1.6523843763546828|
# |68-ChromaDeviationstd|1.6143801426269682|
# |36-Energystd         |1.5140366187292145|
# |22-ChromaVector1m    |1.4767672468111124|
# |32-ChromaVector11m   |1.4283850694922808|
# |26-ChromaVector5m    |1.4104092122246885|
# |10-MFCCs2m           |1.2961097393828782|
# |12-MFCCs4m           |1.193467931116323 |
# |49-MFCCs7std         |1.1821746485804263|
# |18-MFCCs10m          |1.1782275209227497|
# |50-MFCCs8std         |1.144852893002729 |
# |43-MFCCs1std         |1.1427998758084612|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -7.6896700720487985
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |9-MFCCs1m             |4.739871460115653 |
# |3-EnergyEntropym      |4.388098062814511 |
# |71-BPMessentia        |2.764019004567372 |
# |63-ChromaVector8std   |2.7038720907924905|
# |36-Energystd          |2.0474608019307694|
# |60-ChromaVector5std   |1.7682706509277646|
# |17-MFCCs9m            |1.6785115100140744|
# |62-ChromaVector7std   |1.54631532910499  |
# |54-MFCCs12std         |1.5164008383007408|
# |46-MFCCs4std          |1.4046624901723694|
# |38-SpectralCentroidstd|1.3661976976403452|
# |40-SpectralEntropystd |1.3233499844760552|
# |55-MFCCs13std         |1.246165928155722 |
# |23-ChromaVector2m     |1.2442435378243897|
# |58-ChromaVector3std   |1.2360921387994135|
# |57-ChromaVector2std   |1.231738771738245 |
# |42-SpectralRolloffstd |1.0959716092941352|
# |43-MFCCs1std          |0.9624629036043308|
# |41-SpectralFluxstd    |0.8672594085204247|
# |2-Energym             |0.7894983202224487|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.0622163939863425
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |56-ChromaVector1std |5.2314359497771035|
# |9-MFCCs1m           |3.1756404788421797|
# |69-BPM              |2.8513308019651533|
# |11-MFCCs3m          |1.8100719466248103|
# |50-MFCCs8std        |1.7173195179252445|
# |62-ChromaVector7std |1.6188539962988773|
# |26-ChromaVector5m   |1.6048158850562846|
# |58-ChromaVector3std |1.582302387115841 |
# |18-MFCCs10m         |1.5264299357432625|
# |43-MFCCs1std        |1.5148296015408742|
# |27-ChromaVector6m   |1.452468924989288 |
# |45-MFCCs3std        |1.4466565753102731|
# |39-SpectralSpreadstd|1.2949126464214031|
# |67-ChromaVector12std|1.1179366297335631|
# |21-MFCCs13m         |1.1172412597246617|
# |32-ChromaVector11m  |1.073976140709007 |
# |49-MFCCs7std        |1.05336321358041  |
# |35-ZCRstd           |0.9281224469723546|
# |66-ChromaVector11std|0.6912190612972543|
# |65-ChromaVector10std|0.6622811676391108|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.090944983386418
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |70-BPMconf           |6.961884253377895 |
# |69-BPM               |3.456421099276205 |
# |63-ChromaVector8std  |3.1807086274294902|
# |68-ChromaDeviationstd|2.076753468909717 |
# |13-MFCCs5m           |2.0594238135098677|
# |2-Energym            |1.885780357042215 |
# |67-ChromaVector12std |1.838160735146352 |
# |9-MFCCs1m            |1.6171760450412362|
# |14-MFCCs6m           |1.4567913365253364|
# |46-MFCCs4std         |1.409138372700896 |
# |25-ChromaVector4m    |1.4075826365453785|
# |5-SpectralSpreadm    |1.2967248561088993|
# |71-BPMessentia       |1.1930970873131055|
# |52-MFCCs10std        |1.1122136215288008|
# |48-MFCCs6std         |1.111049244195367 |
# |61-ChromaVector6std  |0.9639321659071837|
# |1-ZCRm               |0.899809474050205 |
# |49-MFCCs7std         |0.8260907949529261|
# |3-EnergyEntropym     |0.8039889596680334|
# |47-MFCCs5std         |0.7462623457400314|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  6.765093572544723
# Top 20 Coefficients:
# +----------------------+-------------------+
# |feature               |coeff              |
# +----------------------+-------------------+
# |2-Energym             |3.8233451311589532 |
# |13-MFCCs5m            |3.7406727184085544 |
# |70-BPMconf            |2.9576446351848436 |
# |7-SpectralFluxm       |2.4688080007343824 |
# |45-MFCCs3std          |2.317816778520396  |
# |38-SpectralCentroidstd|1.957983184116741  |
# |56-ChromaVector1std   |1.9472965459650484 |
# |30-ChromaVector9m     |1.6935849747232175 |
# |1-ZCRm                |1.633707066752092  |
# |21-MFCCs13m           |1.5686754900482944 |
# |29-ChromaVector8m     |1.5262898952821562 |
# |15-MFCCs7m            |1.2771489797017377 |
# |23-ChromaVector2m     |1.0478940845217786 |
# |44-MFCCs2std          |1.0245988484160746 |
# |28-ChromaVector7m     |1.017298102760124  |
# |71-BPMessentia        |0.5246671580875486 |
# |14-MFCCs6m            |0.3253018227852612 |
# |4-SpectralCentroidm   |0.30518666069326555|
# |66-ChromaVector11std  |0.2973375364216114 |
# |20-MFCCs12m           |0.12804298142217638|
# +----------------------+-------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.2332392375258205
# Top 20 Coefficients:
# +-------------------+------------------+
# |feature            |coeff             |
# +-------------------+------------------+
# |69-BPM             |3.8150231531175045|
# |44-MFCCs2std       |3.649973067185445 |
# |36-Energystd       |3.3128711113308387|
# |27-ChromaVector6m  |2.959198618038363 |
# |63-ChromaVector8std|2.840421377227517 |
# |18-MFCCs10m        |2.7950176476397206|
# |55-MFCCs13std      |2.447905894619942 |
# |3-EnergyEntropym   |1.9120740856012242|
# |29-ChromaVector8m  |1.9001564188820246|
# |54-MFCCs12std      |1.8205539772372419|
# |49-MFCCs7std       |1.8067354704375425|
# |24-ChromaVector3m  |1.6002556375688248|
# |48-MFCCs6std       |1.1772636871084923|
# |14-MFCCs6m         |0.9955039052395115|
# |46-MFCCs4std       |0.8351108996354454|
# |58-ChromaVector3std|0.8265303856373132|
# |53-MFCCs11std      |0.7466794975800365|
# |34-ChromaDeviationm|0.7253022117480111|
# |52-MFCCs10std      |0.7215074826693859|
# |2-Energym          |0.6997580584933999|
# +-------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.109665147732806
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |59-ChromaVector4std   |2.4011069101786147|
# |71-BPMessentia        |2.333704447549519 |
# |46-MFCCs4std          |2.116834229509877 |
# |11-MFCCs3m            |2.0397554519573284|
# |64-ChromaVector9std   |1.918278471366016 |
# |43-MFCCs1std          |1.8034944086046343|
# |21-MFCCs13m           |1.740783885967152 |
# |38-SpectralCentroidstd|1.4236435649890726|
# |36-Energystd          |1.3545896759843585|
# |40-SpectralEntropystd |1.2665455821276255|
# |63-ChromaVector8std   |1.243462633061736 |
# |54-MFCCs12std         |1.1015099132673072|
# |9-MFCCs1m             |1.091838009120617 |
# |57-ChromaVector2std   |1.0525493700865005|
# |35-ZCRstd             |1.0381751936295405|
# |55-MFCCs13std         |0.9681364513134664|
# |53-MFCCs11std         |0.9509701300680359|
# |15-MFCCs7m            |0.8997931863372028|
# |52-MFCCs10std         |0.7758060705506046|
# |42-SpectralRolloffstd |0.6879896788878789|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.032808692569819
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |37-EnergyEntropystd  |3.3353743364203687|
# |68-ChromaDeviationstd|2.8224715801820666|
# |60-ChromaVector5std  |2.2285775404424517|
# |49-MFCCs7std         |2.0550028937305242|
# |39-SpectralSpreadstd |1.975990875605835 |
# |11-MFCCs3m           |1.613382008035449 |
# |15-MFCCs7m           |1.5534842299719138|
# |20-MFCCs12m          |1.4557220348380626|
# |56-ChromaVector1std  |1.3569948535154581|
# |70-BPMconf           |1.3140510544592094|
# |53-MFCCs11std        |1.293592676322111 |
# |9-MFCCs1m            |1.194731321006111 |
# |36-Energystd         |1.1732072723728708|
# |58-ChromaVector3std  |1.0549481950677952|
# |47-MFCCs5std         |0.9693352187947343|
# |16-MFCCs8m           |0.9083518870573495|
# |23-ChromaVector2m    |0.9062046670138859|
# |18-MFCCs10m          |0.8955652941636821|
# |5-SpectralSpreadm    |0.8554375503104207|
# |48-MFCCs6std         |0.8032020783072852|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -5.907667148644658
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |43-MFCCs1std          |4.629663304787441 |
# |41-SpectralFluxstd    |4.368284564258287 |
# |7-SpectralFluxm       |3.723725712040427 |
# |29-ChromaVector8m     |2.7114629226491456|
# |21-MFCCs13m           |2.6865501937062555|
# |39-SpectralSpreadstd  |2.5455025208635016|
# |71-BPMessentia        |2.2813598498706678|
# |23-ChromaVector2m     |1.9692372108321492|
# |59-ChromaVector4std   |1.766808355182687 |
# |45-MFCCs3std          |1.6689417376678417|
# |20-MFCCs12m           |1.4368121259571334|
# |33-ChromaVector12m    |1.3052309740876942|
# |38-SpectralCentroidstd|1.3051827188123588|
# |25-ChromaVector4m     |1.2798909202519333|
# |22-ChromaVector1m     |1.1760796984731785|
# |28-ChromaVector7m     |1.1308264245583173|
# |18-MFCCs10m           |1.1153300999493718|
# |44-MFCCs2std          |0.9733524674901951|
# |42-SpectralRolloffstd |0.962888308219006 |
# |34-ChromaDeviationm   |0.9514950075486351|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -2.6114538746164415
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |32-ChromaVector11m    |2.6273640190310377|
# |10-MFCCs2m            |2.4372438157106973|
# |55-MFCCs13std         |2.017702540149424 |
# |36-Energystd          |1.914057721263273 |
# |63-ChromaVector8std   |1.794024320661676 |
# |26-ChromaVector5m     |1.7835201126519002|
# |70-BPMconf            |1.7795261085380571|
# |12-MFCCs4m            |1.6681783249675448|
# |29-ChromaVector8m     |1.6437045127086385|
# |38-SpectralCentroidstd|1.6293972503545915|
# |61-ChromaVector6std   |1.6119145416111211|
# |21-MFCCs13m           |1.382491646562855 |
# |41-SpectralFluxstd    |1.255007304869069 |
# |58-ChromaVector3std   |1.013074392716704 |
# |42-SpectralRolloffstd |0.9804462897200757|
# |39-SpectralSpreadstd  |0.8937151245262249|
# |13-MFCCs5m            |0.8848344284969608|
# |51-MFCCs9std          |0.8538758832338538|
# |27-ChromaVector6m     |0.8502799764915999|
# |17-MFCCs9m            |0.8226188422312741|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  1.4278148107886615
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |71-BPMessentia       |6.640073306434145 |
# |29-ChromaVector8m    |3.944109390642647 |
# |7-SpectralFluxm      |3.9176136089429927|
# |69-BPM               |2.8723285987540463|
# |62-ChromaVector7std  |2.7957140690926137|
# |9-MFCCs1m            |2.6462474382845493|
# |41-SpectralFluxstd   |2.589067250673332 |
# |63-ChromaVector8std  |2.5543418725974116|
# |66-ChromaVector11std |2.150065845628758 |
# |68-ChromaDeviationstd|2.038437729815847 |
# |67-ChromaVector12std |1.8145274053726228|
# |57-ChromaVector2std  |1.540378435455477 |
# |27-ChromaVector6m    |1.3154023568652191|
# |17-MFCCs9m           |1.2832800980967611|
# |31-ChromaVector10m   |1.191207802226362 |
# |61-ChromaVector6std  |1.0096130556350835|
# |20-MFCCs12m          |0.8488770180589217|
# |49-MFCCs7std         |0.8173856568154539|
# |36-Energystd         |0.7590474428566722|
# |33-ChromaVector12m   |0.7146836690250724|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -6.950375297361005
# Top 20 Coefficients:
# +---------------------+------------------+
# |feature              |coeff             |
# +---------------------+------------------+
# |59-ChromaVector4std  |3.8843312500261358|
# |47-MFCCs5std         |3.0333509439032373|
# |63-ChromaVector8std  |2.984458130593428 |
# |39-SpectralSpreadstd |2.148396762877882 |
# |67-ChromaVector12std |2.1283922373995585|
# |68-ChromaDeviationstd|2.1255693457936227|
# |34-ChromaDeviationm  |2.055180703825679 |
# |27-ChromaVector6m    |1.9298407420828527|
# |66-ChromaVector11std |1.6108421806452395|
# |69-BPM               |1.5754317063919518|
# |45-MFCCs3std         |1.5259763510864932|
# |32-ChromaVector11m   |1.455245202902768 |
# |12-MFCCs4m           |1.4150350104117653|
# |53-MFCCs11std        |1.4056565492229147|
# |51-MFCCs9std         |1.399865271633601 |
# |15-MFCCs7m           |1.355830708166008 |
# |46-MFCCs4std         |1.2847604343637415|
# |55-MFCCs13std        |1.2805728196808337|
# |37-EnergyEntropystd  |1.257563896429232 |
# |50-MFCCs8std         |1.1592565363376435|
# +---------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -4.027396124955637
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |41-SpectralFluxstd    |2.882626960150456 |
# |11-MFCCs3m            |2.794599544086826 |
# |35-ZCRstd             |2.4350216005954026|
# |25-ChromaVector4m     |2.3505533904117684|
# |43-MFCCs1std          |2.32844539232953  |
# |71-BPMessentia        |2.068200689029402 |
# |29-ChromaVector8m     |1.5585178719417425|
# |13-MFCCs5m            |1.4600349156957162|
# |12-MFCCs4m            |1.42100127092224  |
# |42-SpectralRolloffstd |1.4040366001806546|
# |38-SpectralCentroidstd|1.3710741167389677|
# |48-MFCCs6std          |1.2759559651219583|
# |51-MFCCs9std          |1.2549587306437846|
# |54-MFCCs12std         |1.2438230185978172|
# |23-ChromaVector2m     |1.0793662654289826|
# |47-MFCCs5std          |1.070267258477098 |
# |30-ChromaVector9m     |1.0336539092254329|
# |65-ChromaVector10std  |0.9854838979693221|
# |17-MFCCs9m            |0.9041444405883968|
# |45-MFCCs3std          |0.8955042205250994|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -3.8829295453992443
# Top 20 Coefficients:
# +----------------------+------------------+
# |feature               |coeff             |
# +----------------------+------------------+
# |18-MFCCs10m           |2.7062660611105067|
# |14-MFCCs6m            |2.2074613914883763|
# |22-ChromaVector1m     |1.810734441898859 |
# |59-ChromaVector4std   |1.8099566977234705|
# |19-MFCCs11m           |1.6918207933323401|
# |36-Energystd          |1.628315322642952 |
# |71-BPMessentia        |1.4361231230946772|
# |25-ChromaVector4m     |1.3519152440312745|
# |15-MFCCs7m            |1.3494224307352631|
# |56-ChromaVector1std   |1.291018001734202 |
# |38-SpectralCentroidstd|1.2619167003735354|
# |41-SpectralFluxstd    |1.2227183423862642|
# |65-ChromaVector10std  |1.1384183386294933|
# |7-SpectralFluxm       |1.1278252169200669|
# |44-MFCCs2std          |1.1096923300831827|
# |33-ChromaVector12m    |1.1050815409565768|
# |42-SpectralRolloffstd |1.0177864482730263|
# |21-MFCCs13m           |0.9705785496870895|
# |10-MFCCs2m            |0.968487843971644 |
# |45-MFCCs3std          |0.9504886769151193|
# +----------------------+------------------+
# only showing top 20 rows
#
# None
# Intercept:  -1.6004486084579024
# Top 20 Coefficients:
# +--------------------+------------------+
# |feature             |coeff             |
# +--------------------+------------------+
# |66-ChromaVector11std|2.07614515547445  |
# |41-SpectralFluxstd  |1.9799274578755164|
# |19-MFCCs11m         |1.9628532332134558|
# |5-SpectralSpreadm   |1.9223223725224616|
# |30-ChromaVector9m   |1.6878440831892112|
# |23-ChromaVector2m   |1.6625143933025435|
# |9-MFCCs1m           |1.6569150551720597|
# |59-ChromaVector4std |1.637444012399932 |
# |71-BPMessentia      |1.6259616731689062|
# |7-SpectralFluxm     |1.5940145717198944|
# |62-ChromaVector7std |1.5369821751435895|
# |56-ChromaVector1std |1.5239247684188837|
# |3-EnergyEntropym    |1.3589675775888432|
# |60-ChromaVector5std |1.3249016954691277|
# |21-MFCCs13m         |1.2166802935225274|
# |17-MFCCs9m          |1.1866353118669015|
# |4-SpectralCentroidm |1.0825021692714978|
# |65-ChromaVector10std|1.012638864562205 |
# |25-ChromaVector4m   |0.9032250656024038|
# |27-ChromaVector6m   |0.8140005663722303|
# +--------------------+------------------+
# only showing top 20 rows
#
# None
# +----------+------+
# |Classifier|Result|
# +----------+------+
# |OneVsRest |44.85 |
# +----------+------+

# %% [markdown]
# ## Make a recommendation to a user!

# %%
predictions = OVR_BestModel.transform(test)

# %%
# From the output earlier we saw that the new label for BigRoom is now 21.0
# Let's get a song from there
count = predictions.filter("label!=21.0 AND prediction == 21.0").count()
print(count)
predictions.filter("label!=21.0 AND prediction == 21.0").show()
# predictions.show()
# Out:
# 8
# +-----+--------------------+--------------------+----------+
# |label|            features|       rawPrediction|prediction|
# +-----+--------------------+--------------------+----------+
# |  6.0|[0.36117260545393...|[-2.1603912117929...|      21.0|
# |  7.0|[0.27419559694221...|[-5.4492064734061...|      21.0|
# | 17.0|[0.22307168460494...|[-6.6030087222751...|      21.0|
# | 17.0|[0.24690950657943...|[-5.3862152222757...|      21.0|
# | 17.0|[0.29653807690588...|[-4.1185608720185...|      21.0|
# | 20.0|[0.31510440214688...|[-4.7468092161822...|      21.0|
# | 20.0|[0.33728432608828...|[-4.3475349317382...|      21.0|
# | 20.0|[0.34565765181533...|[-5.9645097496643...|      21.0|
# +-----+--------------------+--------------------+----------+
